# %%
import numpy as np
import pandas as pd
import pprint
import matplotlib.pyplot as plt
from scipy import stats
from collections import Counter

# %%
# helper to make command to get files

c = 'scp -T -i id_rsa_abba agdmt@hai.uni-bremen.de:"'

for i in range(0, 79):
    c_new = '~/bias/xai_priming/0_' + str(i) + '.csv '
    c += c_new

c = c[:-1]
c += '" /Users/laura/Programming/Projects/xai_priming/data_analysis'

print(c)
# Out:
# scp -T -i id_rsa_abba agdmt@hai.uni-bremen.de:"~/bias/xai_priming/0_0.csv ~/bias/xai_priming/0_1.csv ~/bias/xai_priming/0_2.csv ~/bias/xai_priming/0_3.csv ~/bias/xai_priming/0_4.csv ~/bias/xai_priming/0_5.csv ~/bias/xai_priming/0_6.csv ~/bias/xai_priming/0_7.csv ~/bias/xai_priming/0_8.csv ~/bias/xai_priming/0_9.csv ~/bias/xai_priming/0_10.csv ~/bias/xai_priming/0_11.csv ~/bias/xai_priming/0_12.csv ~/bias/xai_priming/0_13.csv ~/bias/xai_priming/0_14.csv ~/bias/xai_priming/0_15.csv ~/bias/xai_priming/0_16.csv ~/bias/xai_priming/0_17.csv ~/bias/xai_priming/0_18.csv ~/bias/xai_priming/0_19.csv ~/bias/xai_priming/0_20.csv ~/bias/xai_priming/0_21.csv ~/bias/xai_priming/0_22.csv ~/bias/xai_priming/0_23.csv ~/bias/xai_priming/0_24.csv ~/bias/xai_priming/0_25.csv ~/bias/xai_priming/0_26.csv ~/bias/xai_priming/0_27.csv ~/bias/xai_priming/0_28.csv ~/bias/xai_priming/0_29.csv ~/bias/xai_priming/0_30.csv ~/bias/xai_priming/0_31.csv ~/bias/xai_priming/0_32.csv ~/bias/xai_priming/0_33.csv ~/bias/xai_priming/0_34.csv ~/bias/xai_priming/0_35.csv ~/bias/xai_priming/0_36.csv ~/bias/xai_priming/0_37.csv ~/bias/xai_priming/0_38.csv ~/bias/xai_priming/0_39.csv ~/bias/xai_priming/0_40.csv ~/bias/xai_priming/0_41.csv ~/bias/xai_priming/0_42.csv ~/bias/xai_priming/0_43.csv ~/bias/xai_priming/0_44.csv ~/bias/xai_priming/0_45.csv ~/bias/xai_priming/0_46.csv ~/bias/xai_priming/0_47.csv ~/bias/xai_priming/0_48.csv ~/bias/xai_priming/0_49.csv ~/bias/xai_priming/0_50.csv ~/bias/xai_priming/0_51.csv ~/bias/xai_priming/0_52.csv ~/bias/xai_priming/0_53.csv ~/bias/xai_priming/0_54.csv ~/bias/xai_priming/0_55.csv ~/bias/xai_priming/0_56.csv ~/bias/xai_priming/0_57.csv ~/bias/xai_priming/0_58.csv ~/bias/xai_priming/0_59.csv ~/bias/xai_priming/0_60.csv ~/bias/xai_priming/0_61.csv ~/bias/xai_priming/0_62.csv ~/bias/xai_priming/0_63.csv ~/bias/xai_priming/0_64.csv ~/bias/xai_priming/0_65.csv ~/bias/xai_priming/0_66.csv ~/bias/xai_priming/0_67.csv ~/bias/xai_priming/0_68.csv ~/bias/xai_priming/0_69.csv ~/bias/xai_priming/0_70.csv ~/bias/xai_priming/0_71.csv ~/bias/xai_priming/0_72.csv ~/bias/xai_priming/0_73.csv ~/bias/xai_priming/0_74.csv ~/bias/xai_priming/0_75.csv ~/bias/xai_priming/0_76.csv ~/bias/xai_priming/0_77.csv ~/bias/xai_priming/0_78.csv" /Users/laura/Programming/Projects/xai_priming/data_analysis

# %%
# helper to make command to get files

c = 'scp -T -i id_rsa_abba agdmt@hai.uni-bremen.de:"'

for i in range(0, 80):
    c_new = '~/bias/xai_priming/1_' + str(i) + '.csv '
    c += c_new

c = c[:-1]
c += '" /Users/laura/Programming/Projects/xai_priming/data_analysis'

print(c)
# Out:
# scp -T -i id_rsa_abba agdmt@hai.uni-bremen.de:"~/bias/xai_priming/1_0.csv ~/bias/xai_priming/1_1.csv ~/bias/xai_priming/1_2.csv ~/bias/xai_priming/1_3.csv ~/bias/xai_priming/1_4.csv ~/bias/xai_priming/1_5.csv ~/bias/xai_priming/1_6.csv ~/bias/xai_priming/1_7.csv ~/bias/xai_priming/1_8.csv ~/bias/xai_priming/1_9.csv ~/bias/xai_priming/1_10.csv ~/bias/xai_priming/1_11.csv ~/bias/xai_priming/1_12.csv ~/bias/xai_priming/1_13.csv ~/bias/xai_priming/1_14.csv ~/bias/xai_priming/1_15.csv ~/bias/xai_priming/1_16.csv ~/bias/xai_priming/1_17.csv ~/bias/xai_priming/1_18.csv ~/bias/xai_priming/1_19.csv ~/bias/xai_priming/1_20.csv ~/bias/xai_priming/1_21.csv ~/bias/xai_priming/1_22.csv ~/bias/xai_priming/1_23.csv ~/bias/xai_priming/1_24.csv ~/bias/xai_priming/1_25.csv ~/bias/xai_priming/1_26.csv ~/bias/xai_priming/1_27.csv ~/bias/xai_priming/1_28.csv ~/bias/xai_priming/1_29.csv ~/bias/xai_priming/1_30.csv ~/bias/xai_priming/1_31.csv ~/bias/xai_priming/1_32.csv ~/bias/xai_priming/1_33.csv ~/bias/xai_priming/1_34.csv ~/bias/xai_priming/1_35.csv ~/bias/xai_priming/1_36.csv ~/bias/xai_priming/1_37.csv ~/bias/xai_priming/1_38.csv ~/bias/xai_priming/1_39.csv ~/bias/xai_priming/1_40.csv ~/bias/xai_priming/1_41.csv ~/bias/xai_priming/1_42.csv ~/bias/xai_priming/1_43.csv ~/bias/xai_priming/1_44.csv ~/bias/xai_priming/1_45.csv ~/bias/xai_priming/1_46.csv ~/bias/xai_priming/1_47.csv ~/bias/xai_priming/1_48.csv ~/bias/xai_priming/1_49.csv ~/bias/xai_priming/1_50.csv ~/bias/xai_priming/1_51.csv ~/bias/xai_priming/1_52.csv ~/bias/xai_priming/1_53.csv ~/bias/xai_priming/1_54.csv ~/bias/xai_priming/1_55.csv ~/bias/xai_priming/1_56.csv ~/bias/xai_priming/1_57.csv ~/bias/xai_priming/1_58.csv ~/bias/xai_priming/1_59.csv ~/bias/xai_priming/1_60.csv ~/bias/xai_priming/1_61.csv ~/bias/xai_priming/1_62.csv ~/bias/xai_priming/1_63.csv ~/bias/xai_priming/1_64.csv ~/bias/xai_priming/1_65.csv ~/bias/xai_priming/1_66.csv ~/bias/xai_priming/1_67.csv ~/bias/xai_priming/1_68.csv ~/bias/xai_priming/1_69.csv ~/bias/xai_priming/1_70.csv ~/bias/xai_priming/1_71.csv ~/bias/xai_priming/1_72.csv ~/bias/xai_priming/1_73.csv ~/bias/xai_priming/1_74.csv ~/bias/xai_priming/1_75.csv ~/bias/xai_priming/1_76.csv ~/bias/xai_priming/1_77.csv ~/bias/xai_priming/1_78.csv ~/bias/xai_priming/1_79.csv" /Users/laura/Programming/Projects/xai_priming/data_analysis

# %% [markdown]
# # Read and format data
#
# ## Sample DF
#
# Get sample df to check correct decision and AI decision for each task.

# %%
df = pd.read_csv("sample_string.csv", index_col = "Index")
df
# Out:
#       Marital status              Application mode  \
# Index
# 648           Single              Change in course
# 2781          Single  1st phase—general contingent
# 2883         Married             Over 23 years old
# 266           Single  2nd phase—general contingent
# 2537          Single  1st phase—general contingent
# 2791          Single  1st phase—general contingent
# 1576         Married             Over 23 years old
# 988           Single  1st phase—general contingent
# 3232          Single  1st phase—general contingent
# 3214          Single  1st phase—general contingent
# 131           Single  2nd phase—general contingent
# 3920          Single  1st phase—general contingent
# 3575          Single  1st phase—general contingent
# 3053          Single  2nd phase—general contingent
# 4096        Divorced             Over 23 years old
#
#        University's position in preferences when applying  \
# Index
# 648                                                    2
# 2781                                                   1
# 2883                                                   1
# 266                                                    4
# 2537                                                   1
# 2791                                                   1
# 1576                                                   2
# 988                                                    1
# 3232                                                   2
# 3214                                                   4
# 131                                                    2
# 3920                                                   5
# 3575                                                   1
# 3053                                                   1
# 4096                                                   1
#
#                                      Course Daytime/evening attendance  \
# Index
# 648                            Oral Hygiene                    daytime
# 2781                        Basic Education                    daytime
# 2883    Social Service (evening attendance)                    evening
# 266                                 Nursing                    daytime
# 2537   Advertising and Marketing Management                    daytime
# 2791                     Veterinary Nursing                    daytime
# 1576   Advertising and Marketing Management                    daytime
# 988                          Social Service                    daytime
# 3232           Journalism and Communication                    daytime
# 3214                   Communication Design                    daytime
# 131                    Communication Design                    daytime
# 3920                         Social Service                    daytime
# 3575                          Equiniculture                    daytime
# 3053                     Veterinary Nursing                    daytime
# 4096    Social Service (evening attendance)                    evening
#
#                                   Previous qualification Nationality  \
# Index
# 648                                  Secondary education  Portuguese
# 2781                                 Secondary education  Portuguese
# 2883                                 Secondary education  Portuguese
# 266                                  Secondary education  Portuguese
# 2537                                 Secondary education  Portuguese
# 2791                                 Secondary education  Portuguese
# 1576   Basic education 3rd cycle (9th/10th/11th year)...  Portuguese
# 988                                  Secondary education  Portuguese
# 3232                                 Secondary education  Portuguese
# 3214                                 Secondary education  Portuguese
# 131                                  Secondary education  Portuguese
# 3920                                 Secondary education  Portuguese
# 3575                                 Secondary education  Portuguese
# 3053                                 Secondary education  Portuguese
# 4096   Basic education 3rd cycle (9th/10th/11th year)...  Portuguese
#
#                                   Mother's qualification  \
# Index
# 648    Secondary Education—12th Year of Schooling or ...
# 2781         2nd cycle of the general high school course
# 2883       General Course of Administration and Commerce
# 266                     Higher Education—master’s degree
# 2537                             General commerce course
# 2791         Supplementary Accounting and Administration
# 1576       General Course of Administration and Commerce
# 988                   Higher Education—bachelor’s degree
# 3232                             General commerce course
# 3214                             Higher Education—degree
# 131        General Course of Administration and Commerce
# 3920         Supplementary Accounting and Administration
# 3575                    Higher Education—master’s degree
# 3053         Supplementary Accounting and Administration
# 4096       General Course of Administration and Commerce
#
#                                   Father's qualification  \
# Index
# 648    Basic Education 3rd Cycle (9th/10th/11th Year)...
# 2781   Basic education 1st cycle (4th/5th year) or eq...
# 2883   Basic education 1st cycle (4th/5th year) or eq...
# 266    Secondary Education—12th Year of Schooling or ...
# 2537   Basic Education 3rd Cycle (9th/10th/11th Year)...
# 2791   Basic Education 3rd Cycle (9th/10th/11th Year)...
# 1576   Basic education 1st cycle (4th/5th year) or eq...
# 988                   Higher Education—bachelor’s degree
# 3232   Basic Education 2nd Cycle (6th/7th/8th Year) o...
# 3214                             Higher Education—degree
# 131    Basic education 1st cycle (4th/5th year) or eq...
# 3920   Secondary Education—12th Year of Schooling or ...
# 3575                             Higher Education—degree
# 3053   Basic Education 3rd Cycle (9th/10th/11th Year)...
# 4096   Basic education 1st cycle (4th/5th year) or eq...
#
#                                      Mother's occupation  ...  \
# Index                                                     ...
# 648                                 Administrative staff  ...
# 2781                                   Unskilled Workers  ...
# 2883                                   Unskilled Workers  ...
# 266    Specialists in Intellectual and Scientific Act...  ...
# 2537   Skilled Workers in Industry, Construction, and...  ...
# 2791                                   Unskilled Workers  ...
# 1576                                   Unskilled Workers  ...
# 988       Intermediate Level Technicians and Professions  ...
# 3232      Intermediate Level Technicians and Professions  ...
# 3214   Specialists in Intellectual and Scientific Act...  ...
# 131                                    Unskilled Workers  ...
# 3920                                   Unskilled Workers  ...
# 3575      Intermediate Level Technicians and Professions  ...
# 3053                                             Student  ...
# 4096                                   Unskilled Workers  ...
#
#       Curricular units 2nd sem enrolled  \
# Index
# 648                                   8
# 2781                                  6
# 2883                                  6
# 266                                   8
# 2537                                  6
# 2791                                  6
# 1576                                  6
# 988                                   6
# 3232                                  6
# 3214                                  6
# 131                                   6
# 3920                                  6
# 3575                                  6
# 3053                                  5
# 4096                                  6
#
#       Total exams across all classes in 2nd sem  \
# Index
# 648                                          10
# 2781                                         14
# 2883                                          8
# 266                                           8
# 2537                                          6
# 2791                                          8
# 1576                                          9
# 988                                          12
# 3232                                          6
# 3214                                          6
# 131                                           6
# 3920                                         13
# 3575                                          9
# 3053                                          9
# 4096                                          6
#
#       Curricular units 2nd sem passed Curricular units 2nd sem grade  \
# Index
# 648                                 8                      13.212500
# 2781                                1                      11.000000
# 2883                                6                      11.500000
# 266                                 7                      14.828571
# 2537                                6                      15.833333
# 2791                                6                      14.142857
# 1576                                4                      13.750000
# 988                                 2                      10.000000
# 3232                                5                      12.600000
# 3214                                6                      15.166667
# 131                                 6                      13.000000
# 3920                                3                      11.000000
# 3575                                6                      14.857143
# 3053                                3                      13.000000
# 4096                                6                      15.500000
#
#       Curricular units 2nd sem without exams Unemployment rate at enrollment  \
# Index
# 648                                        0                            10.8
# 2781                                       0                            10.8
# 2883                                       0                             8.9
# 266                                        0                            12.7
# 2537                                       0                            12.4
# 2791                                       0                            11.1
# 1576                                       0                            12.4
# 988                                        0                            11.1
# 3232                                       0                            12.7
# 3214                                       0                             9.4
# 131                                        0                             7.6
# 3920                                       0                             9.4
# 3575                                       0                            11.1
# 3053                                       0                             7.6
# 4096                                       0                            11.1
#
#       Inflation rate at enrollment  GDP at enrollment    Target  AI prediction
# Index
# 648                            1.4               1.74  Graduate       Graduate
# 2781                           1.4               1.74   Dropout        Dropout
# 2883                           1.4               3.51  Graduate       Graduate
# 266                            3.7              -1.70  Graduate       Graduate
# 2537                           0.5               1.79  Graduate       Graduate
# 2791                           0.6               2.02  Graduate       Graduate
# 1576                           0.5               1.79   Dropout        Dropout
# 988                            0.6               2.02   Dropout        Dropout
# 3232                           3.7              -1.70  Graduate       Graduate
# 3214                          -0.8              -3.12  Graduate       Graduate
# 131                            2.6               0.32  Graduate       Graduate
# 3920                          -0.8              -3.12  Graduate        Dropout
# 3575                           0.6               2.02  Graduate        Dropout
# 3053                           2.6               0.32   Dropout       Graduate
# 4096                           0.6               2.02  Graduate        Dropout
#
# [15 rows x 36 columns]

# %% [markdown]
# ## Participants
#
# **Overview**
#
# There are 2x2 groups:
#
# - w = w (with) explanations
# - wo = w/o (without) explanations
#
# and
#
# - 0 = no priming = participant gets to make a decision, then sees AI suggestion, then makes final decision
# - 1 = yes priming = participant sees AI suggestion immediately
#
# makes for the following four prefixes for participants indices: w_0_, w_1_, wo_0_, wo_1_.
#
# **Next: Demographic Data**
#
# Get demographic data from prolific into df, to check id and save total time taken to remove outliers.
# If we want, we can also have a look at the demographic distribution, or do some exploratory analysis with this stuff.

# %%
df_demo_wo = pd.read_csv("demo_data_wo.csv", index_col = "Participant id")
df_demo_w = pd.read_csv("demo_data_xai.csv", index_col = "Participant id")
df_demo = pd.concat([df_demo_wo, df_demo_w])
print(df_demo.shape)
df_demo
# Out:
# (300, 18)
#                                      Submission id    Status  \
# Participant id
# 642c63f27d35b896cfbc4976  64f78c3a1f128588d084b371  APPROVED
# 5e6f58ba2649e051077d8988  64f78c41b5cb4da7fe7aa0d3  APPROVED
# 605da94ba47f45380a1c7d57  64f78c41d10237d1e4e3d939  APPROVED
# 603ea08e7dc2aaf9eb6d9225  64f78c540fe28f8105ec57e3  APPROVED
# 60f672ca5ca3b52915f16c9d  64f78c54b3d1411f234fe43e  APPROVED
# ...                                            ...       ...
# 5f1398cfb075423b3da590ce  64ff7d9c0599765e89854922  APPROVED
# 64ecd34cb2a8b9bef9c78e6e  64ff7da3a2a075ec5fef6d08  APPROVED
# 5ee24db25079946d034e6a37  64ff7f328b56869d058fbb9c  APPROVED
# 5d0aa9aa5047d20018b8490d  64ff7fbdfffbcd241c55e856  APPROVED
# 6166e78051425fa22de68491  64ff8dec21e507da14fdb7d4  APPROVED
#
#                                            Started at  \
# Participant id
# 642c63f27d35b896cfbc4976  2023-09-05T20:14:59.894000Z
# 5e6f58ba2649e051077d8988  2023-09-05T20:14:57.310000Z
# 605da94ba47f45380a1c7d57  2023-09-05T20:14:57.702000Z
# 603ea08e7dc2aaf9eb6d9225  2023-09-05T20:15:16.196000Z
# 60f672ca5ca3b52915f16c9d  2023-09-05T20:15:16.605000Z
# ...                                               ...
# 5f1398cfb075423b3da590ce  2023-09-11T20:50:40.802000Z
# 64ecd34cb2a8b9bef9c78e6e  2023-09-11T20:51:23.685000Z
# 5ee24db25079946d034e6a37  2023-09-11T20:57:22.614000Z
# 5d0aa9aa5047d20018b8490d  2023-09-11T20:59:41.072000Z
# 6166e78051425fa22de68491  2023-09-11T22:00:21.161000Z
#
#                                          Completed at  \
# Participant id
# 642c63f27d35b896cfbc4976  2023-09-05T20:38:33.071000Z
# 5e6f58ba2649e051077d8988  2023-09-05T20:28:16.362000Z
# 605da94ba47f45380a1c7d57  2023-09-05T20:22:06.433000Z
# 603ea08e7dc2aaf9eb6d9225  2023-09-05T20:23:46.436000Z
# 60f672ca5ca3b52915f16c9d  2023-09-05T20:30:30.224000Z
# ...                                               ...
# 5f1398cfb075423b3da590ce  2023-09-11T21:04:50.186000Z
# 64ecd34cb2a8b9bef9c78e6e  2023-09-11T21:13:00.615000Z
# 5ee24db25079946d034e6a37  2023-09-11T21:07:40.564000Z
# 5d0aa9aa5047d20018b8490d  2023-09-11T21:07:57.713000Z
# 6166e78051425fa22de68491  2023-09-11T22:11:34.421000Z
#
#                                           Reviewed at  \
# Participant id
# 642c63f27d35b896cfbc4976   2023-09-06T07:33:44.327000
# 5e6f58ba2649e051077d8988   2023-09-05T20:28:16.965000
# 605da94ba47f45380a1c7d57   2023-09-05T20:22:07.105000
# 603ea08e7dc2aaf9eb6d9225  2023-09-05T20:24:04.911000Z
# 60f672ca5ca3b52915f16c9d   2023-09-05T20:30:31.099000
# ...                                               ...
# 5f1398cfb075423b3da590ce   2023-09-11T21:04:50.883000
# 64ecd34cb2a8b9bef9c78e6e   2023-09-11T21:13:01.617000
# 5ee24db25079946d034e6a37   2023-09-11T21:07:41.526000
# 5d0aa9aa5047d20018b8490d   2023-09-11T21:07:59.456000
# 6166e78051425fa22de68491   2023-09-11T22:11:35.415000
#
#                                           Archived at  Time taken  \
# Participant id
# 642c63f27d35b896cfbc4976  2023-09-05T20:38:40.316993Z        1414
# 5e6f58ba2649e051077d8988  2023-09-05T20:28:16.902221Z         800
# 605da94ba47f45380a1c7d57  2023-09-05T20:22:07.037274Z         429
# 603ea08e7dc2aaf9eb6d9225  2023-09-05T20:24:15.886731Z         511
# 60f672ca5ca3b52915f16c9d  2023-09-05T20:30:31.031170Z         914
# ...                                               ...         ...
# 5f1398cfb075423b3da590ce  2023-09-11T21:04:50.815876Z         850
# 64ecd34cb2a8b9bef9c78e6e  2023-09-11T21:13:01.538351Z        1297
# 5ee24db25079946d034e6a37  2023-09-11T21:07:41.433468Z         618
# 5d0aa9aa5047d20018b8490d  2023-09-11T21:07:59.397845Z         497
# 6166e78051425fa22de68491  2023-09-11T22:11:35.349070Z         674
#
#                                    Completion code  Total approvals  Age  \
# Participant id
# 642c63f27d35b896cfbc4976  642c63f27d35b896cfbc4976               92   19
# 5e6f58ba2649e051077d8988                  C13E0WG5              411   37
# 605da94ba47f45380a1c7d57                  C13E0WG5              232   30
# 603ea08e7dc2aaf9eb6d9225                  C13E0WG5              196   21
# 60f672ca5ca3b52915f16c9d                  C13E0WG5               70   37
# ...                                            ...              ...  ...
# 5f1398cfb075423b3da590ce                  C13E0WG5               26   21
# 64ecd34cb2a8b9bef9c78e6e                  C13E0WG5                2   31
# 5ee24db25079946d034e6a37                  C13E0WG5              270   31
# 5d0aa9aa5047d20018b8490d                  C13E0WG5              317   24
# 6166e78051425fa22de68491                  C13E0WG5              465   22
#
#                              Sex Ethnicity simplified Country of birth  \
# Participant id
# 642c63f27d35b896cfbc4976    Male                White      Netherlands
# 5e6f58ba2649e051077d8988    Male                Mixed     South Africa
# 605da94ba47f45380a1c7d57  Female                White           Poland
# 603ea08e7dc2aaf9eb6d9225  Female                White     South Africa
# 60f672ca5ca3b52915f16c9d  Female                Black     South Africa
# ...                          ...                  ...              ...
# 5f1398cfb075423b3da590ce    Male                White           Mexico
# 64ecd34cb2a8b9bef9c78e6e    Male                White         Portugal
# 5ee24db25079946d034e6a37  Female                White         Portugal
# 5d0aa9aa5047d20018b8490d    Male                White         Portugal
# 6166e78051425fa22de68491  Female                White         Portugal
#
#                          Country of residence   Nationality    Language  \
# Participant id
# 642c63f27d35b896cfbc4976          Netherlands   Netherlands       Dutch
# 5e6f58ba2649e051077d8988         South Africa  South Africa     English
# 605da94ba47f45380a1c7d57               Poland        Poland      Polish
# 603ea08e7dc2aaf9eb6d9225         South Africa  South Africa     English
# 60f672ca5ca3b52915f16c9d         South Africa  South Africa     English
# ...                                       ...           ...         ...
# 5f1398cfb075423b3da590ce               Mexico        Mexico     Spanish
# 64ecd34cb2a8b9bef9c78e6e             Portugal      Portugal  Portuguese
# 5ee24db25079946d034e6a37             Portugal      Portugal  Portuguese
# 5d0aa9aa5047d20018b8490d             Portugal      Portugal  Portuguese
# 6166e78051425fa22de68491             Portugal      Portugal  Portuguese
#
#                          Student status             Employment status
# Participant id
# 642c63f27d35b896cfbc4976            Yes  Unemployed (and job seeking)
# 5e6f58ba2649e051077d8988   DATA_EXPIRED                  DATA_EXPIRED
# 605da94ba47f45380a1c7d57             No                     Full-Time
# 603ea08e7dc2aaf9eb6d9225            Yes                     Part-Time
# 60f672ca5ca3b52915f16c9d   DATA_EXPIRED                  DATA_EXPIRED
# ...                                 ...                           ...
# 5f1398cfb075423b3da590ce            Yes                     Part-Time
# 64ecd34cb2a8b9bef9c78e6e            Yes                     Full-Time
# 5ee24db25079946d034e6a37   DATA_EXPIRED                  DATA_EXPIRED
# 5d0aa9aa5047d20018b8490d             No                     Full-Time
# 6166e78051425fa22de68491            Yes  Unemployed (and job seeking)
#
# [300 rows x 18 columns]

# %% [markdown]
# ## Results files
#
# Results files are read line by line and saved into three big dicts (see comments below).
# First, lets have a look at one example to understand the structure:

# %%
with open("explanations_w/0_3.csv") as file:
    lines = file.readlines()
lines
# Out:
# ['Prolific ID,611bf41079ffca32db5a3080\n',
#  '2781,DROPOUT,DROPOUT,1694415892.6133816,1694415896.2987952,1694415907.1762483\n',
#  '2537,GRADUATE,GRADUATE,1694415973.0875223,1694415974.9286497,1694415982.622102\n',
#  '2791,GRADUATE,GRADUATE,1694416033.243505,1694416034.9364398,1694416041.8506386\n',
#  '3575,GRADUATE,DROPOUT,1694416084.2088904,1694416085.4903047,1694416123.1231546\n',
#  '4096,GRADUATE,DROPOUT,1694416160.1438067,1694416161.2751198,1694416180.9886925\n',
#  '131,GRADUATE,GRADUATE,1694416251.4282892,1694416252.4801354,1694416261.015837\n',
#  '3053,DROPOUT,DROPOUT,1694416330.9089692,1694416332.829107,1694416342.2451599\n',
#  '988,GRADUATE,GRADUATE,1694416418.6374807,1694416419.9399676,1694416431.6364324\n',
#  '266,GRADUATE,GRADUATE,1694416465.861412,1694416467.154555,1694416469.714263\n',
#  '3232,DROPOUT,DROPOUT,1694416514.1614063,1694416515.4007359,1694416530.5137973\n',
#  '1576,DROPOUT,DROPOUT,1694416568.3268626,1694416569.3057497,1694416575.7579436\n',
#  '648,DROPOUT,GRADUATE,1694416624.7767775,1694416625.792135,1694416631.726417\n',
#  '2883,DROPOUT,GRADUATE,1694416672.6503973,1694416674.3790479,1694416688.2962139\n',
#  '3214,GRADUATE,GRADUATE,1694416726.3007314,1694416727.3622222,1694416731.5944383\n',
#  '3920,DROPOUT,DROPOUT,1694416770.1308126,1694416771.0503523,1694416773.53985\n',
#  '2,YES,i frequently use it at my workplace.\n',
#  '3,13\n',
#  'know,NEUTRAL\n',
#  'fai_3,NEUTRAL\n',
#  'rel_1,AGREE\n',
#  'fai_4,DISAGREE\n',
#  'fai_2,AGREE\n',
#  'com_1,AGREE\n',
#  'rel_5,STRONGLY AGREE\n',
#  'fai_5,AGREE\n',
#  'com_5,STRONGLY AGREE\n',
#  'com_2,STRONGLY AGREE\n',
#  'rel_2,DISAGREE\n',
#  'fai_1,NEUTRAL\n',
#  'com_3,AGREE\n']

# %%
# likert results are converted into numbers in order to calculate trust score
likert_calc = {"STRONGLY AGREE":2, "AGREE":1, "NEUTRAL":0, "DISAGREE":-1, "STRONGLY DISAGREE":-2}

# %%
participants_results = {}
participants_tasks = {}
participants_hct = {}
prolific_check = []

for x_group in ["wo", "w"]: 

    for group in range(2):

        for p in range(100):

            p_id = x_group + "_" + str(group) + "_" + str(p)
            test_file = "explanations_" + x_group + "/" + str(group) + "_" + str(p) + ".csv"
            
            try:
                with open(test_file) as file:
                    lines = file.readlines()
            except:
                #print("group done")
                continue

            # test if file is complete (should have 31 lines if questionnaire was completed)
            if not len(lines) == 31:
                print(p_id, "- unvollstaendig/falsch - ")
                continue
            print(p_id)

            # set up dicts
            # data is stored in three tables in the end, because otherwise it would have to multi-dimensional
            #     - results, which is the one we will mainly be looking at, with one line per participant
            #       here, results from htc are averaged and agreement, switch_ratio etc have been calculated
            #     - tasks is two dimensional: for each participant and student_id combo info about that task can be found
            #     - htc just holds the htc answers in one row per participant
            participant = {"file":test_file, "explanation_group":x_group, "priming_group":group, 
                           "participant_number":p, "final_accuracy":0, "ai_agreement":0, 
                           "n_na":0, "n_wt":0, "n_wmt":0, "n_ut":0, "n_ot":0}
            tasks = {}
            hct = {}

            for i, l in enumerate(lines):

                l = l.strip()
                line = l.split(",")

                # line 0: prolific ID
                if i == 0:
                    participant[line[0]] = line[1]
                    prolific_check.append(line[1])
                    # check if this person is missing from the prolific list
                    if not line[1] in list(df_demo.index): 
                        print("!!! not in demo", line[1])
                        participant["time_taken"] = -1
                    else:
                        # get total time taken from prolific data
                        time_taken = int(df_demo.loc[line[1]]['Time taken'])
                        participant["time_taken"] = time_taken
                        participant["language"] = df_demo.loc[line[1]]['Language']
                        participant["total_approvals"] = df_demo.loc[line[1]]['Total approvals']

                # lines 1-15: tasks
                elif i < 16:

                    student_id = int(line[0])
                    correct_decision = df.loc[student_id]['Target'].upper()
                    AI_decision = df.loc[student_id]['AI prediction'].upper()

                    tasks[student_id] = {}

                    # group 0 - user first
                    if len(line) == 6: 

                        # check that length of lines corresponds with group that participant should be in
                        if not "priming" in participant:
                            participant["priming"] = False # meaning user gets to make decision first
                            assert participant["priming"] == participant["priming_group"]

                        # we will count how often user was correct, accuracy to be calculated later
                        if not "user_accuracy" in participant:
                            participant["user_accuracy"] = 0

                        # calculate times and decision correctness
                        user_time = float(line[4]) - float(line[3])
                        final_time = float(line[5]) - float(line[4])
                        user_decision = line[1]
                        final_decision = line[2]
                        user_correct = (correct_decision == user_decision)
                        if user_correct:
                            participant["user_accuracy"] += 1

                        tasks[student_id]["user_time"] = user_time
                        tasks[student_id]["user_decision"] = user_decision
                        tasks[student_id]["user_decision_correct"] = user_correct

                        # check what kind of trust there was
                        # this is only applicable if user decision differed from AI decision, otherwise "na"
                        # here we also count the number of each
                        if user_decision == AI_decision:
                            participant["n_na"] += 1
                        else:
                            if AI_decision == correct_decision:
                                if final_decision == AI_decision:
                                    participant["n_wt"] += 1 # warranted trust - AI correct, user switched
                                else:
                                    participant["n_ut"] += 1 # undertrust - AI correct, no switch
                            else:
                                if final_decision == AI_decision:
                                    participant["n_ot"] += 1 # overtrust - AI incorrect, user switched
                                else:
                                    participant["n_wmt"] += 1 # warranted mistrust - AI incorrect, no switch

                    # group one - AI priming, user doesn't get to make first decision on their own
                    else: 

                        if not "priming" in participant:
                            participant["priming"] = True # meaning user gets to make decision first
                            assert participant["priming"] == participant["priming_group"]

                        final_time = float(line[3]) - float(line[2])
                        final_decision = line[1]

                    # also count how often final decision was correct
                    final_decision_correct = (final_decision == correct_decision)
                    if final_decision_correct:
                        participant["final_accuracy"] += 1

                    # and count how often user agreed with AI
                    if final_decision == AI_decision:
                        participant["ai_agreement"] += 1

                    tasks[student_id]["final_decision"] = final_decision
                    tasks[student_id]["final_decision_correct"] = final_decision_correct
                    tasks[student_id]["final_time"] = final_time

                # now come the questionnaire questions
                # line 16: AI knowledge
                elif i == 16: 

                    participant["AI_knowledge"] = line[1:]

                # line 17: perceived accuracy (given out of 15, calculated as percentage here)
                elif i == 17: # user perceived accuracy

                    participant["perceived_accuracy"] = int(line[1])/15

                # line 18: user perceived knowledge (likert)
                elif i == 18:

                    assert line[0] == "know"
                    participant["perceived_domain_knowledge"] = likert_calc[line[1]]

                # following lines: hct questionnaire likert questions
                else:

                    hct[line[0]] = likert_calc[line[1]]

            # for group 0, calculate switch ratio
            participant["switch_ratio"] = 0
            participant["switch_not_ratio"] = 0
            if group == 0:
                participant["switch_ratio"] = (participant["n_wt"] + participant["n_ot"])/(15 - participant["n_na"])
                participant["switch_not_ratio"] = (participant["n_wmt"] + participant["n_ut"])/(15 - participant["n_na"])

            # reformat results of hct, calculate averages and total trust value
            trust_values = list(hct.values())
            participant["total_trust"] = np.mean(trust_values)

            trust = {"fai":[], "com":[], "rel":[]}

            for key in hct:
                if "fai" in key:
                    trust["fai"].append(hct[key])
                if "com" in key:
                    trust["com"].append(hct[key])
                if "rel" in key:
                    trust["rel"].append(hct[key])

            participant["fai"] = np.mean(trust["fai"])
            participant["com"] = np.mean(trust["com"])
            participant["rel"] = np.mean(trust["rel"])

            # calculate accuracy (user and final) and ai agreement as percentage from counts collected above
            final_accuracy = participant["final_accuracy"]/15
            participant["final_accuracy"] = final_accuracy
            if "user_accuracy" in participant:
                user_accuracy = participant["user_accuracy"]/15
                participant["user_accuracy"] = user_accuracy
            ai_agreement = participant["ai_agreement"]
            participant["ai_agreement"] = ai_agreement/15

            # save everything in big dicts
            participants_results[p_id] = participant
            participants_tasks[p_id] = tasks
            participants_hct[p_id] = hct

            #pprint.pprint(participant)
            #pprint.pprint(tasks)
            #pprint.pprint(hct)

            #print("---")

print(len(participants_results))

print("\n Prolific check:")
print("In demo but not files:", [i for i in df_demo.index if not i in prolific_check])
print("In files but not demo:", [i for i in prolific_check if not i in df_demo.index])
# Out:
# wo_0_0
# wo_0_1
# wo_0_2 - unvollstaendig/falsch -
# wo_0_3
# wo_0_4
# wo_0_5
# wo_0_6
# wo_0_7
# wo_0_8
# wo_0_9
# wo_0_10
# wo_0_11
# wo_0_12
# wo_0_13
# wo_0_14
# wo_0_15
# wo_0_16
# wo_0_17
# wo_0_18
# wo_0_19
# wo_0_20
# wo_0_21
# wo_0_22
# wo_0_23
# wo_0_24
# wo_0_25
# wo_0_26
# wo_0_27
# wo_0_28 - unvollstaendig/falsch -
# wo_0_29 - unvollstaendig/falsch -
# wo_0_30
# wo_0_31 - unvollstaendig/falsch -
# wo_0_32 - unvollstaendig/falsch -
# wo_0_33
# wo_0_34
# wo_0_35
# wo_0_36 - unvollstaendig/falsch -
# wo_0_37
# wo_0_38
# wo_0_39
# wo_0_40
# wo_0_41
# wo_0_42
# wo_0_43
# wo_0_44
# wo_0_45
# wo_0_46
# wo_0_47
# wo_0_48
# wo_0_49
# wo_0_50
# wo_0_51
# wo_0_52 - unvollstaendig/falsch -
# wo_0_53
# wo_0_54
# wo_0_55
# wo_0_56
# wo_0_57
# wo_0_58
# wo_0_59
# wo_0_60
# wo_0_61
# wo_0_62
# wo_0_63 - unvollstaendig/falsch -
# wo_0_64
# wo_0_65
# wo_0_66
# wo_0_67
# wo_0_68
# wo_0_69
# wo_0_70
# wo_0_71
# wo_0_72
# wo_0_73
# wo_0_74
# wo_0_75
# wo_0_76
# wo_0_77
# wo_0_78 - unvollstaendig/falsch -
# wo_0_79
# wo_0_80
# wo_0_81
# !!! not in demo 60ef2e52a188d9859f92bb58
# wo_1_0
# wo_1_1
# wo_1_2
# wo_1_3 - unvollstaendig/falsch -
# wo_1_4
# wo_1_5
# wo_1_6
# wo_1_7
# wo_1_8
# wo_1_9
# wo_1_10
# wo_1_11
# wo_1_12 - unvollstaendig/falsch -
# wo_1_13
# wo_1_14
# wo_1_15
# wo_1_16
# wo_1_17
# wo_1_18 - unvollstaendig/falsch -
# wo_1_19
# wo_1_20
# wo_1_21
# wo_1_22
# wo_1_23
# wo_1_24
# wo_1_25
# wo_1_26
# wo_1_27
# wo_1_28
# wo_1_29
# wo_1_30
# wo_1_31
# wo_1_32
# wo_1_33
# wo_1_34
# wo_1_35
# wo_1_36
# wo_1_37
# wo_1_38
# wo_1_39
# wo_1_40
# wo_1_41
# wo_1_42
# wo_1_43
# wo_1_44
# wo_1_45
# wo_1_46
# wo_1_47
# wo_1_48
# wo_1_49
# wo_1_50
# wo_1_51
# wo_1_52
# wo_1_53
# wo_1_54
# wo_1_55
# wo_1_56
# wo_1_57
# wo_1_58
# wo_1_59
# wo_1_60
# wo_1_61
# wo_1_62 - unvollstaendig/falsch -
# wo_1_63
# wo_1_64
# wo_1_65
# wo_1_66
# wo_1_67
# wo_1_68
# wo_1_69
# wo_1_70
# wo_1_71
# wo_1_72
# wo_1_73
# wo_1_74
# wo_1_75
# wo_1_76
# wo_1_77
# wo_1_78
# wo_1_79
# wo_1_80
# wo_1_81
# w_0_0
# w_0_1
# w_0_2 - unvollstaendig/falsch -
# w_0_3
# w_0_4
# w_0_5
# w_0_6
# w_0_7
# w_0_8 - unvollstaendig/falsch -
# w_0_9
# w_0_10
# w_0_11
# w_0_12
# w_0_13
# w_0_14
# w_0_15
# w_0_16
# w_0_17
# w_0_18
# w_0_19 - unvollstaendig/falsch -
# w_0_20
# w_0_21 - unvollstaendig/falsch -
# w_0_22
# w_0_23
# w_0_24
# w_0_25
# w_0_26
# w_0_27
# w_0_28
# w_0_29
# w_0_30
# w_0_31
# w_0_32
# w_0_33
# w_0_34
# w_0_35
# w_0_36
# w_0_37
# w_0_38
# w_0_39
# w_0_40
# w_0_41
# w_0_42
# w_0_43
# w_0_44
# w_0_45
# w_0_46
# w_0_47
# w_0_48
# w_0_49
# w_0_50
# w_0_51
# w_0_52
# w_0_53
# w_0_54
# w_0_55 - unvollstaendig/falsch -
# w_0_56
# w_0_57
# w_0_58
# w_0_59
# w_0_60
# w_0_61
# w_0_62
# w_0_63
# w_0_64
# w_0_65
# w_0_66
# w_0_67
# w_0_68
# w_0_69
# w_0_70
# w_0_71
# w_0_72
# w_0_73
# w_0_74
# w_0_75
# w_0_76
# w_0_77
# w_0_78
# w_1_0
# w_1_1
# w_1_2
# w_1_3
# w_1_4
# w_1_5
# w_1_6
# w_1_7
# w_1_8
# w_1_9
# w_1_10
# w_1_11 - unvollstaendig/falsch -
# w_1_12
# w_1_13
# w_1_14
# w_1_15
# w_1_16
# w_1_17
# w_1_18
# w_1_19
# w_1_20
# w_1_21
# w_1_22
# w_1_23
# w_1_24
# w_1_25
# w_1_26
# w_1_27
# w_1_28 - unvollstaendig/falsch -
# w_1_29 - unvollstaendig/falsch -
# w_1_30
# w_1_31
# w_1_32
# w_1_33
# w_1_34
# w_1_35
# w_1_36
# w_1_37
# w_1_38
# w_1_39
# w_1_40
# w_1_41
# w_1_42
# w_1_43
# w_1_44
# w_1_45
# w_1_46
# w_1_47
# w_1_48
# w_1_49
# w_1_50
# w_1_51
# w_1_52
# w_1_53 - unvollstaendig/falsch -
# w_1_54
# w_1_55
# w_1_56
# w_1_57
# w_1_58
# !!! not in demo 603d7ba0ecb86cc51ed2e12c
# w_1_59
# w_1_60
# w_1_61
# w_1_62
# w_1_63
# w_1_64
# w_1_65
# w_1_66
# w_1_67
# w_1_68
# w_1_69
# w_1_70
# w_1_71
# w_1_72
# w_1_73
# w_1_74
# w_1_75
# w_1_76
# w_1_77
# w_1_78 - unvollstaendig/falsch -
# w_1_79
# 300
#
#  Prolific check:
# In demo but not files: ['5bc9e85c77740000016a04bd', '5f1b768bba959b371da3e65f']
# In files but not demo: ['60ef2e52a188d9859f92bb58', '603d7ba0ecb86cc51ed2e12c']

# %%
results = pd.DataFrame.from_dict(participants_results, orient='index')
results = results[results["time_taken"] != -1]
print(results.shape)
results
# Out:
# (298, 26)
#                            file explanation_group  priming_group  \
# wo_0_0  explanations_wo/0_0.csv                wo              0
# wo_0_1  explanations_wo/0_1.csv                wo              0
# wo_0_3  explanations_wo/0_3.csv                wo              0
# wo_0_4  explanations_wo/0_4.csv                wo              0
# wo_0_5  explanations_wo/0_5.csv                wo              0
# ...                         ...               ...            ...
# w_1_74  explanations_w/1_74.csv                 w              1
# w_1_75  explanations_w/1_75.csv                 w              1
# w_1_76  explanations_w/1_76.csv                 w              1
# w_1_77  explanations_w/1_77.csv                 w              1
# w_1_79  explanations_w/1_79.csv                 w              1
#
#         participant_number  final_accuracy  ai_agreement  n_na  n_wt  n_wmt  \
# wo_0_0                   0        0.466667      0.600000     7     0      1
# wo_0_1                   1        0.800000      0.800000     9     2      2
# wo_0_3                   3        0.866667      0.733333    10     1      3
# wo_0_4                   4        1.000000      0.733333    10     1      4
# wo_0_5                   5        0.800000      0.800000     8     3      2
# ...                    ...             ...           ...   ...   ...    ...
# w_1_74                  74        0.866667      0.733333     0     0      0
# w_1_75                  75        0.733333      0.733333     0     0      0
# w_1_76                  76        0.800000      0.666667     0     0      0
# w_1_77                  77        0.800000      0.800000     0     0      0
# w_1_79                  79        0.800000      0.666667     0     0      0
#
#         n_ut  ...  user_accuracy  \
# wo_0_0     5  ...       0.600000
# wo_0_1     1  ...       0.733333
# wo_0_3     1  ...       0.800000
# wo_0_4     0  ...       0.933333
# wo_0_5     1  ...       0.666667
# ...      ...  ...            ...
# w_1_74     0  ...            NaN
# w_1_75     0  ...            NaN
# w_1_76     0  ...            NaN
# w_1_77     0  ...            NaN
# w_1_79     0  ...            NaN
#
#                                              AI_knowledge  perceived_accuracy  \
# wo_0_0                                             [NO, ]            0.666667
# wo_0_1                                             [NO, ]            0.733333
# wo_0_3  [YES, Through ChatGPT,  as well as discussions...            0.866667
# wo_0_4  [YES, I am in a master of artificial inteligen...            0.800000
# wo_0_5    [YES, I come into contact with ai in chat bots]            0.600000
# ...                                                   ...                 ...
# w_1_74                                [YES, chatgpt etc.]            0.533333
# w_1_75                                             [NO, ]            0.466667
# w_1_76                                    [YES, Chat GPT]            0.666667
# w_1_77  [YES, I have some works where AI is applied in...            0.666667
# w_1_79                                             [NO, ]            0.733333
#
#        perceived_domain_knowledge  switch_ratio  switch_not_ratio  \
# wo_0_0                          1      0.250000          0.750000
# wo_0_1                          0      0.500000          0.500000
# wo_0_3                          0      0.200000          0.800000
# wo_0_4                          1      0.200000          0.800000
# wo_0_5                          2      0.571429          0.428571
# ...                           ...           ...               ...
# w_1_74                         -1      0.000000          0.000000
# w_1_75                          0      0.000000          0.000000
# w_1_76                          1      0.000000          0.000000
# w_1_77                          1      0.000000          0.000000
# w_1_79                          1      0.000000          0.000000
#
#         total_trust  fai   com       rel
# wo_0_0     0.250000 -0.2  0.75  0.333333
# wo_0_1    -0.250000 -1.0  0.25  0.333333
# wo_0_3    -0.666667 -1.0 -0.50 -0.333333
# wo_0_4     0.000000 -0.4  0.25  0.333333
# wo_0_5     0.583333  0.8  0.50  0.333333
# ...             ...  ...   ...       ...
# w_1_74    -1.500000 -0.8 -2.00 -2.000000
# w_1_75     0.250000  0.2  0.25  0.333333
# w_1_76     0.083333 -0.4  0.00  1.000000
# w_1_77    -0.333333 -0.2 -0.25 -0.666667
# w_1_79     0.083333 -0.6  0.25  1.000000
#
# [298 rows x 26 columns]

# %% [markdown]
# # Remove Outliers/Bad Faith
#
# ## Find Outliers
#
# As can be seen below, there are no participants who are extremely bad or who took extremely little time compared to others.

# %%
fig, ax = plt.subplots()
acc_data = results["final_accuracy"]#[~np.isnan(results["time_taken"])]
VP = ax.boxplot(acc_data)
ax.set_ylim(0,1.1)
plt.show()

# %%
fig, ax = plt.subplots()
time_data = results["time_taken"][~np.isnan(results["time_taken"])]
VP = ax.boxplot(time_data)
plt.show()

# %%
np.mean(time_data)
# Out:
# 904.0872483221476

# %% [markdown]
# I also checked if anything obviously changes if we e.g. remove everybody who took less than ten minutes in total. The result is that this doesn't change anything - there does not seem to be a qualitative difference in the data of the people who took longer or less long.

# %% [markdown]
# Next idea: lets look at the time taken for each task, and see if there are any super low outliers there.

# %%
task_list = list(participants_tasks['wo_0_0'].keys())

len(task_list)
# Out:
# 15

# %%
wo_0_user = {}
wo_0_final = {}
wo_1_final = {}
w_0_user = {}
w_0_final = {}
w_1_final = {}

time_per_p_0 = {"user":{}, "final":{}, "total":{}}
time_per_p_1 = {}

for p in participants_tasks:
    
    if p[3] == "0" or p[2] == "0":
        time_per_p_0["user"][p] = []
        time_per_p_0["final"][p] = []
        time_per_p_0["total"][p] = []
    elif p[3] == "1" or p[2] == "1":
        time_per_p_1[p] = []
    else:
        print(p[2], p[3], "error")
    
    for t in participants_tasks[p]:
        if not t in wo_0_user:
            wo_0_user[t] = []
        if not t in wo_0_final:
            wo_0_final[t] = []
        if not t in wo_1_final:
            wo_1_final[t] = []
        if not t in w_0_user:
            w_0_user[t] = []
        if not t in w_0_final:
            w_0_final[t] = []
        if not t in w_1_final:
            w_1_final[t] = []
            
        if p[:2] == "wo":
            if p[3] == "0":
                wo_0_user[t].append(participants_tasks[p][t]["user_time"])
                wo_0_final[t].append(participants_tasks[p][t]["final_time"])
                time_per_p_0["user"][p].append(participants_tasks[p][t]["user_time"])
                time_per_p_0["final"][p].append(participants_tasks[p][t]["final_time"])
                time_per_p_0["total"][p].append(participants_tasks[p][t]["user_time"] + participants_tasks[p][t]["final_time"])
            else:
                wo_1_final[t].append(participants_tasks[p][t]["final_time"])
                time_per_p_1[p].append(participants_tasks[p][t]["final_time"])
        else:
            if p[2] == "0":
                w_0_user[t].append(participants_tasks[p][t]["user_time"])
                w_0_final[t].append(participants_tasks[p][t]["final_time"])
                time_per_p_0["user"][p].append(participants_tasks[p][t]["user_time"])
                time_per_p_0["final"][p].append(participants_tasks[p][t]["final_time"])
                time_per_p_0["total"][p].append(participants_tasks[p][t]["user_time"] + participants_tasks[p][t]["final_time"])
            else:
                w_1_final[t].append(participants_tasks[p][t]["final_time"])
                time_per_p_1[p].append(participants_tasks[p][t]["final_time"])
                
#pprint.pprint(wo_0_user)
                
for t in wo_0_user:
    wo_0_user[t] = np.mean(wo_0_user[t])
    wo_0_final[t] = np.mean(wo_0_final[t])
    wo_1_final[t] = np.mean(wo_1_final[t])
    w_0_user[t] = np.mean(w_0_user[t])
    w_0_final[t] = np.mean(w_0_final[t])
    w_1_final[t] = np.mean(w_1_final[t])

data_wo_means = {"wo_0_user":list(wo_0_user.values()),
                 "wo_0_final":list(wo_0_final.values()),
                 "wo_1_final":list(wo_1_final.values())
                }

data_w_means = {"w_0_user":list(w_0_user.values()),
                 "w_0_final":list(w_0_final.values()),
                 "w_1_final":list(w_1_final.values())
                }

time_per_p_0["user"] = {p:np.mean(time_per_p_0["user"][p]) for p in time_per_p_0["user"]}
time_per_p_0["final"] = {p:np.mean(time_per_p_0["final"][p]) for p in time_per_p_0["final"]}
time_per_p_0["total"] = {p:np.mean(time_per_p_0["total"][p]) for p in time_per_p_0["total"]}
time_per_p_1 = {p:np.mean(time_per_p_1[p]) for p in time_per_p_1}

print("Group 0, user time")
print("mean:", np.mean(list(time_per_p_0["user"].values())))
print("min:", min(list(time_per_p_0["user"].values())))
print("Group 0, final time")
print("mean:", np.mean(list(time_per_p_0["final"].values())))
print("min:", min(list(time_per_p_0["final"].values())))
print("Group 0, total time")
print("mean:", np.mean(list(time_per_p_0["total"].values())))
print("min:", min(list(time_per_p_0["total"].values())))
print("Group 1")
print("mean:", np.mean(list(time_per_p_1.values())))
print("min:", min(list(time_per_p_1.values())))

time_per_user_data = [list(time_per_p_0["user"].values()), list(time_per_p_0["final"].values()), 
                      list(time_per_p_0["total"].values()), list(time_per_p_1.values())]
labels = ["Group 0, user", "Group 0, final", "Group 0, total", "Group 1, final"]

fig, axs = plt.subplots(ncols = 4, nrows = 1, figsize=(8, 6))
for i in range(4):
    VP = axs[i].boxplot(time_per_user_data[i])
    axs[i].title.set_text(labels[i])
    axs[i].set_ylim(0, 100)
plt.show()
# Out:
# Group 0, user time
# mean: 3.1354399391835526
# min: 0.4609909693400065
# Group 0, final time
# mean: 8.008835284211065
# min: 1.4918359438578288
# Group 0, total time
# mean: 11.144275223394615
# min: 2.2936717442103793
# Group 1
# mean: 3.0186921580944186
# min: 0.7953094323476155

# %%
results["time_per_task"] = pd.Series(time_per_p_0["total"]|time_per_p_1)
results
# Out:
#                            file explanation_group  priming_group  \
# wo_0_0  explanations_wo/0_0.csv                wo              0
# wo_0_1  explanations_wo/0_1.csv                wo              0
# wo_0_3  explanations_wo/0_3.csv                wo              0
# wo_0_4  explanations_wo/0_4.csv                wo              0
# wo_0_5  explanations_wo/0_5.csv                wo              0
# ...                         ...               ...            ...
# w_1_74  explanations_w/1_74.csv                 w              1
# w_1_75  explanations_w/1_75.csv                 w              1
# w_1_76  explanations_w/1_76.csv                 w              1
# w_1_77  explanations_w/1_77.csv                 w              1
# w_1_79  explanations_w/1_79.csv                 w              1
#
#         participant_number  final_accuracy  ai_agreement  n_na  n_wt  n_wmt  \
# wo_0_0                   0        0.466667      0.600000     7     0      1
# wo_0_1                   1        0.800000      0.800000     9     2      2
# wo_0_3                   3        0.866667      0.733333    10     1      3
# wo_0_4                   4        1.000000      0.733333    10     1      4
# wo_0_5                   5        0.800000      0.800000     8     3      2
# ...                    ...             ...           ...   ...   ...    ...
# w_1_74                  74        0.866667      0.733333     0     0      0
# w_1_75                  75        0.733333      0.733333     0     0      0
# w_1_76                  76        0.800000      0.666667     0     0      0
# w_1_77                  77        0.800000      0.800000     0     0      0
# w_1_79                  79        0.800000      0.666667     0     0      0
#
#         n_ut  ...                                       AI_knowledge  \
# wo_0_0     5  ...                                             [NO, ]
# wo_0_1     1  ...                                             [NO, ]
# wo_0_3     1  ...  [YES, Through ChatGPT,  as well as discussions...
# wo_0_4     0  ...  [YES, I am in a master of artificial inteligen...
# wo_0_5     1  ...    [YES, I come into contact with ai in chat bots]
# ...      ...  ...                                                ...
# w_1_74     0  ...                                [YES, chatgpt etc.]
# w_1_75     0  ...                                             [NO, ]
# w_1_76     0  ...                                    [YES, Chat GPT]
# w_1_77     0  ...  [YES, I have some works where AI is applied in...
# w_1_79     0  ...                                             [NO, ]
#
#        perceived_accuracy  perceived_domain_knowledge switch_ratio  \
# wo_0_0           0.666667                           1     0.250000
# wo_0_1           0.733333                           0     0.500000
# wo_0_3           0.866667                           0     0.200000
# wo_0_4           0.800000                           1     0.200000
# wo_0_5           0.600000                           2     0.571429
# ...                   ...                         ...          ...
# w_1_74           0.533333                          -1     0.000000
# w_1_75           0.466667                           0     0.000000
# w_1_76           0.666667                           1     0.000000
# w_1_77           0.666667                           1     0.000000
# w_1_79           0.733333                           1     0.000000
#
#         switch_not_ratio  total_trust  fai   com       rel  time_per_task
# wo_0_0          0.750000     0.250000 -0.2  0.75  0.333333       3.353436
# wo_0_1          0.500000    -0.250000 -1.0  0.25  0.333333       4.425740
# wo_0_3          0.800000    -0.666667 -1.0 -0.50 -0.333333       6.221536
# wo_0_4          0.800000     0.000000 -0.4  0.25  0.333333       8.652404
# wo_0_5          0.428571     0.583333  0.8  0.50  0.333333       6.889090
# ...                  ...          ...  ...   ...       ...            ...
# w_1_74          0.000000    -1.500000 -0.8 -2.00 -2.000000       2.174590
# w_1_75          0.000000     0.250000  0.2  0.25  0.333333       3.138306
# w_1_76          0.000000     0.083333 -0.4  0.00  1.000000       2.032701
# w_1_77          0.000000    -0.333333 -0.2 -0.25 -0.666667       3.636001
# w_1_79          0.000000     0.083333 -0.6  0.25  1.000000       3.083460
#
# [298 rows x 27 columns]

# %% [markdown]
# Again, the results show that there are no bottom outliers who took very much less time per task than everybody else. However, it is quite interesting how much longer people take to consider the task if they are given the option to make up their mind first and only then are shown the AI prediction!
#
# Next, we plot the times per task. Here, there is not much of interest. Note that this would not show a decline over time, as the order was randomized. This would need to be implemented seperately.

# %%
x = np.arange(len(task_list))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in data_wo_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Time (s)')
ax.set_title('w/o explanations')
ax.set_xticks(x + width, task_list)
ax.legend(loc='upper left') #, ncols=3)
ax.set_ylim(0, 30)

plt.show()

# %%
x = np.arange(len(task_list))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in data_w_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Time (s)')
ax.set_title('w/ explanations')
ax.set_xticks(x + width, task_list)
ax.legend(loc='upper left') #, ncols=3)
ax.set_ylim(0, 30)

plt.show()

# %% [markdown]
# ## Find Bad Faith/Too Dumb/Too Fast
#
# Additional ideas:
#
# Were there any people who simply always answered the same thing? This would not be found if we remove people with extremely low accuracy, but is otherwise unlikely.
#
# I also considered checking several things (overall accuracy, perceived domain knowledge, language skills, previous approvals of this participant, etc.
# Surprisingly, when rerunning some visualizations with a number of people removed on this basis, there was also no difference in the results. I don't think that simply combining these factors based on gut feeling is a good way to kick out bad faith participants.

# %%
grad_ratio = {}

for p in participants_tasks:
    final_decisions = [participants_tasks[p][t]["final_decision"] for t in participants_tasks[p]]
    final_decisions = Counter(final_decisions)
    ratio = final_decisions["GRADUATE"]/15
    if ratio == 1:
        print(p, final_decisions)
    grad_ratio[p] = ratio
    
results["grad_ratio"] = pd.Series(grad_ratio)
results
# Out:
# wo_1_43 Counter({'GRADUATE': 15})
# wo_1_66 Counter({'GRADUATE': 15})
#                            file explanation_group  priming_group  \
# wo_0_0  explanations_wo/0_0.csv                wo              0
# wo_0_1  explanations_wo/0_1.csv                wo              0
# wo_0_3  explanations_wo/0_3.csv                wo              0
# wo_0_4  explanations_wo/0_4.csv                wo              0
# wo_0_5  explanations_wo/0_5.csv                wo              0
# ...                         ...               ...            ...
# w_1_74  explanations_w/1_74.csv                 w              1
# w_1_75  explanations_w/1_75.csv                 w              1
# w_1_76  explanations_w/1_76.csv                 w              1
# w_1_77  explanations_w/1_77.csv                 w              1
# w_1_79  explanations_w/1_79.csv                 w              1
#
#         participant_number  final_accuracy  ai_agreement  n_na  n_wt  n_wmt  \
# wo_0_0                   0        0.466667      0.600000     7     0      1
# wo_0_1                   1        0.800000      0.800000     9     2      2
# wo_0_3                   3        0.866667      0.733333    10     1      3
# wo_0_4                   4        1.000000      0.733333    10     1      4
# wo_0_5                   5        0.800000      0.800000     8     3      2
# ...                    ...             ...           ...   ...   ...    ...
# w_1_74                  74        0.866667      0.733333     0     0      0
# w_1_75                  75        0.733333      0.733333     0     0      0
# w_1_76                  76        0.800000      0.666667     0     0      0
# w_1_77                  77        0.800000      0.800000     0     0      0
# w_1_79                  79        0.800000      0.666667     0     0      0
#
#         n_ut  ...  perceived_accuracy perceived_domain_knowledge  \
# wo_0_0     5  ...            0.666667                          1
# wo_0_1     1  ...            0.733333                          0
# wo_0_3     1  ...            0.866667                          0
# wo_0_4     0  ...            0.800000                          1
# wo_0_5     1  ...            0.600000                          2
# ...      ...  ...                 ...                        ...
# w_1_74     0  ...            0.533333                         -1
# w_1_75     0  ...            0.466667                          0
# w_1_76     0  ...            0.666667                          1
# w_1_77     0  ...            0.666667                          1
# w_1_79     0  ...            0.733333                          1
#
#         switch_ratio switch_not_ratio  total_trust  fai   com       rel  \
# wo_0_0      0.250000         0.750000     0.250000 -0.2  0.75  0.333333
# wo_0_1      0.500000         0.500000    -0.250000 -1.0  0.25  0.333333
# wo_0_3      0.200000         0.800000    -0.666667 -1.0 -0.50 -0.333333
# wo_0_4      0.200000         0.800000     0.000000 -0.4  0.25  0.333333
# wo_0_5      0.571429         0.428571     0.583333  0.8  0.50  0.333333
# ...              ...              ...          ...  ...   ...       ...
# w_1_74      0.000000         0.000000    -1.500000 -0.8 -2.00 -2.000000
# w_1_75      0.000000         0.000000     0.250000  0.2  0.25  0.333333
# w_1_76      0.000000         0.000000     0.083333 -0.4  0.00  1.000000
# w_1_77      0.000000         0.000000    -0.333333 -0.2 -0.25 -0.666667
# w_1_79      0.000000         0.000000     0.083333 -0.6  0.25  1.000000
#
#         time_per_task  grad_ratio
# wo_0_0       3.353436    0.600000
# wo_0_1       4.425740    0.666667
# wo_0_3       6.221536    0.600000
# wo_0_4       8.652404    0.733333
# wo_0_5       6.889090    0.800000
# ...               ...         ...
# w_1_74       2.174590    0.866667
# w_1_75       3.138306    0.733333
# w_1_76       2.032701    0.933333
# w_1_77       3.636001    0.800000
# w_1_79       3.083460    0.933333
#
# [298 rows x 28 columns]

# %%
# save extended dataframe

results.to_csv("results.csv")

# %% [markdown]
# Okay, lets look at the time per task again for each group, and consider who needs to be kicked based on too little time taken. Lets calculate some percentiles:

# %%
# split into separate dataframes for easy access
results_0 = results[results["priming_group"] == 0]
results_1 = results[results["priming_group"] == 1]
results_w = results[results["explanation_group"] == "w"]
results_wo = results[results["explanation_group"] == "wo"]

# %%
task_times_0 = list(results_0["time_per_task"])

print("People in Group 0:", len(task_times_0))

for thresh in range(10):
    percent = len([t for t in task_times_0 if t<thresh])
    print(f"Under {thresh} seconds:", percent, "people in Group 0")
    
print("---")
print("People in Group 1:", len(task_times_1))

task_times_1 = list(results_1["time_per_task"])

for thresh in range(1, 10):
    percent = len([t for t in task_times_1 if t<thresh])
    print(f"Under {thresh} seconds:", percent, "people in of Group 1")
# Out:
# People in Group 0: 146
# Under 0 seconds: 0 people in Group 0
# Under 1 seconds: 0 people in Group 0
# Under 2 seconds: 0 people in Group 0
# Under 3 seconds: 5 people in Group 0
# Under 4 seconds: 23 people in Group 0
# Under 5 seconds: 33 people in Group 0
# Under 6 seconds: 49 people in Group 0
# Under 7 seconds: 61 people in Group 0
# Under 8 seconds: 77 people in Group 0
# Under 9 seconds: 93 people in Group 0
# ---
# People in Group 1: 152
# Under 1 seconds: 10 people in of Group 1
# Under 2 seconds: 70 people in of Group 1
# Under 3 seconds: 108 people in of Group 1
# Under 4 seconds: 120 people in of Group 1
# Under 5 seconds: 132 people in of Group 1
# Under 6 seconds: 132 people in of Group 1
# Under 7 seconds: 143 people in of Group 1
# Under 8 seconds: 146 people in of Group 1
# Under 9 seconds: 147 people in of Group 1

# %%
# Test: combine different exclusion criteria in different ways - no effect

#df_test_0 = pd.DataFrame([results_0["time_per_task"]<7, 
#                        results_0["user_accuracy"]<0.7,
#                        results_0["time_taken"]<450,
#                        results_0["perceived_domain_knowledge"]<1,
#                        results_0["total_approvals"]<10,
#                        results_0["language"]!="English"
#                       ])
#for c in df_test_0:
#    if sum(list(df_test_0[c]))>4:
#        print(c)
#        participants_to_kick.append(c)
#        
#df_test_1 = pd.DataFrame([results_1["time_per_task"]<7, 
#                        results_1["time_taken"]<450,
#                        results_1["perceived_domain_knowledge"]<1,
#                        results_1["total_approvals"]<10,
#                        results_1["language"]!="English"
#                       ])

#for c in df_test_1:
#    if sum(list(df_test_1[c]))>3:
#        print(c)
#        participants_to_kick.append(c)

# %% [markdown]
# ## Removal
#
# Finally, lets remove those people who either
#
# - always answered grad
#
# or
#
# - took less then 3s in group 0 or less than 1s in group 1

# %%
results_filtered = results[results["grad_ratio"] != 1]
results_filtered = results_filtered[~((results_filtered["priming_group"] == 0) & (results_filtered["time_per_task"]<3))]
results_filtered = results_filtered[~((results_filtered["priming_group"] == 1) & (results_filtered["time_per_task"]<1))]
results_filtered.shape
# Out:
# (281, 28)

# %%
# redo the split
# split into separate dataframes for easy access

# could do with filtered results here
# however, weirdly enough, there is still not any noticeable difference in the results below
# I think it really doesn't matter

results_0 = results[results["priming_group"] == 0]
results_1 = results[results["priming_group"] == 1]
results_w = results[results["explanation_group"] == "w"]
results_wo = results[results["explanation_group"] == "wo"]

results_w_0 = results_0[results_0["explanation_group"] == "w"]
results_w_1 = results_1[results["explanation_group"] == "w"]
results_wo_0 = results_0[results_0["explanation_group"] == "wo"]
results_wo_1 = results_1[results["explanation_group"] == "wo"]

print(results_w_0.shape)
print(results_w_1.shape)
print(results_wo_0.shape)
print(results_wo_1.shape)

# save extended dataframe

results.to_csv("results.csv")
# Out:
# (74, 28)
# (74, 28)
# (72, 28)
# (78, 28)
# /var/folders/ky/d01ywblx1l5fk6g19868_t7m0000gn/T/ipykernel_48144/1326010054.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   results_w_1 = results_1[results["explanation_group"] == "w"]
# /var/folders/ky/d01ywblx1l5fk6g19868_t7m0000gn/T/ipykernel_48144/1326010054.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   results_wo_1 = results_1[results["explanation_group"] == "wo"]

# %%
results.columns
# Out:
# Index(['file', 'explanation_group', 'priming_group', 'participant_number',
#        'final_accuracy', 'ai_agreement', 'n_na', 'n_wt', 'n_wmt', 'n_ut',
#        'n_ot', 'Prolific ID', 'time_taken', 'language', 'total_approvals',
#        'priming', 'user_accuracy', 'AI_knowledge', 'perceived_accuracy',
#        'perceived_domain_knowledge', 'switch_ratio', 'switch_not_ratio',
#        'total_trust', 'fai', 'com', 'rel', 'time_per_task', 'grad_ratio'],
#       dtype='object')

# %% [markdown]
# # Visualization
#
# ## Comparisons between groups
#
# First, lets make some graphics where we can see all four group, or compare either explanation or bias across the whole sample population.

# %%
def compare_priming_groups(column, violin = False):
    
    print(column.upper())
    print("- priming - ")
    
    print(stats.ttest_ind(results_0[column], results_1[column]))

    fig, ax = plt.subplots()
    if violin:
        VP = ax.violinplot([results_0[column], results_1[column]])#, labels = ["no priming", "priming"])
    else:
        VP = ax.boxplot([results_0[column], results_1[column]])#, labels = ["no priming", "priming"])
    ax.set_xticks([1, 2], labels=["w/o priming", "w/ priming"])
    ax.set_title(column)
    plt.show()
    
def compare_explanation_groups(column, violin = False):
    
    print(column.upper())
    print("- explanation - ")
    
    print(stats.ttest_ind(results_w[column], results_wo[column]))

    fig, ax = plt.subplots()
    if violin:
        VP = ax.violinplot([results_wo[column], results_w[column]])#, labels = ["w/ explanation", "w/o explanation"])
    else:
        VP = ax.boxplot([results_wo[column], results_w[column]])#, labels = ["w/ explanation", "w/o explanation"])
    ax.set_xticks([1, 2], labels=["w/o explanation", "w/ explanation"])
    ax.set_title(column)
    plt.show()
    
def compare_all_groups(column, violin = False):
    
    print(column.upper())
    
    print("Difference based on priming/no priming:")
    print(stats.ttest_ind(results_0[column], results_1[column]))
    print("- for without explanation group:")
    print(stats.ttest_ind(results_wo_0[column], results_wo_1[column]))
    print("- for with explanation group")
    print(stats.ttest_ind(results_w_0[column], results_w_1[column]))
    print()
    print("Difference based on explanation/no explanation:")
    print(stats.ttest_ind(results_w[column], results_wo[column]))
    print("- for without priming group:")
    print(stats.ttest_ind(results_wo_0[column], results_w_0[column]))
    print("- for with priming group")
    print(stats.ttest_ind(results_wo_1[column], results_w_1[column]))
    print()
    
    
    #print(stats.ttest_ind(results_w[column], results_wo[column]))

    fig, ax = plt.subplots()
    if violin:
        VP = ax.violinplot([results_wo_0[column], results_wo_1[column], results_w_0[column], results_w_1[column]])
    else:
        VP = ax.boxplot([results_wo_0[column], results_wo_1[column], results_w_0[column], results_w_1[column]])
    ax.set_xticks([1, 2, 3, 4], 
                  labels=["w/o priming \n w/o explanation", 
                          "w/ priming \n w/o explanation", 
                          "w/o priming \n w/ explanation", 
                          "w/ priming \n w/ explanation"])
    ax.set_title(column)
    plt.show()

# %%
compare_all_groups("final_accuracy", violin = False)
# Out:
# FINAL_ACCURACY
# Difference based on priming/no priming:
# Ttest_indResult(statistic=-1.4037406541889186, pvalue=0.16144434182201386)
# - for without explanation group:
# Ttest_indResult(statistic=-1.9553442567456851, pvalue=0.052426200021923275)
# - for with explanation group
# Ttest_indResult(statistic=0.10385208339950427, pvalue=0.917429255164117)
#
# Difference based on explanation/no explanation:
# Ttest_indResult(statistic=0.09930057261623092, pvalue=0.9209668401288491)
# - for without priming group:
# Ttest_indResult(statistic=-1.1312303535810795, pvalue=0.25983858633305956)
# - for with priming group
# Ttest_indResult(statistic=1.03325714358188, pvalue=0.30314659498660984)

# %%
compare_all_groups("total_trust", violin = False)
# Out:
# TOTAL_TRUST
# Difference based on priming/no priming:
# Ttest_indResult(statistic=1.3564553159955148, pvalue=0.17598803781700212)
# - for without explanation group:
# Ttest_indResult(statistic=-0.5121742881738042, pvalue=0.6092924888935387)
# - for with explanation group
# Ttest_indResult(statistic=2.1473331757795844, pvalue=0.03341784800462773)
#
# Difference based on explanation/no explanation:
# Ttest_indResult(statistic=-0.08069996691032538, pvalue=0.9357350989347074)
# - for without priming group:
# Ttest_indResult(statistic=-1.4393339944618317, pvalue=0.15222615684687588)
# - for with priming group
# Ttest_indResult(statistic=1.41100770492706, pvalue=0.1603130050465858)

# %%
compare_all_groups("ai_agreement")
# Out:
# AI_AGREEMENT
# Difference based on priming/no priming:
# Ttest_indResult(statistic=1.888099187901052, pvalue=0.059990498800962896)
# - for without explanation group:
# Ttest_indResult(statistic=0.9216690176730125, pvalue=0.3582012329969604)
# - for with explanation group
# Ttest_indResult(statistic=1.7241033399192687, pvalue=0.08680579489702236)
#
# Difference based on explanation/no explanation:
# Ttest_indResult(statistic=1.0789406066158955, pvalue=0.28149261710802526)
# - for without priming group:
# Ttest_indResult(statistic=-1.209784707368115, pvalue=0.22834380627194154)
# - for with priming group
# Ttest_indResult(statistic=-0.3347633991365567, pvalue=0.7382712259539868)

# %% [markdown]
# ## Correlations

# %%
def scatter(column_x, column_y, dfs, labels, title = None, likert_x = False, likert_y = False):

    fig, ax = plt.subplots()
    
    for i, df in enumerate(dfs):
        SC = ax.scatter(df[column_x], df[column_y], label = labels[i])
        print(labels[i])
        pearsons, p = stats.pearsonr(df[column_x], df[column_y])
        print(pearsons, "p =", p)
        #if p < 0.05:
        #    m, b = np.polyfit(df[column_x], df[column_y], 1)
        #    trend = ax.plot(x, m*x+b)
    ax.set_xlabel(column_x)
    ax.set_ylabel(column_y)
    if likert_x:
        ax.set_xlim(-2.5, 2.5)
    else:
        ax.set_xlim(-0.1, 1.1)
    if likert_y:
        ax.set_ylim(-2.5, 2.5)
    else:
        ax.set_ylim(-0.1, 1.1)
    if not title is None:
        ax.set_title(title)
    ax.legend(loc='lower right') #, ncols=3)
    plt.show()
    
def scatter_subplots(column_x, column_y, dfs, labels, ncols, nrows, 
                     likert_x = False, likert_y = False):
    
    fig, axs = plt.subplots(ncols = ncols, nrows = nrows, figsize = (8, 4*nrows))
    if nrows == 1:
        axs = np.array([axs])
    
    for row in range(nrows):
        for col in range(ncols):
            df = dfs[row][col]
            pearsons, p = stats.pearsonr(df[column_x], df[column_y])
            print(labels[row][col], pearsons, p)
            if p < 0.05:
                color = "green"
            else:
                color = "grey"
            axs[row, col].scatter(df[column_x], df[column_y], c = color)
            axs[row, col].set_title(labels[row][col])
            if row == nrows - 1:
                axs[row, col].set_xlabel(column_x)
            if col == 0:
                axs[row, col].set_ylabel(column_y)
            if likert_x:
                axs[row, col].set_xlim(-2.5, 2.5)
            if likert_y:
                axs[row, col].set_ylim(-2.5, 2.5)

# %%
scatter_subplots("total_trust", "switch_ratio", [[results_wo_0, results_w_0]], 
        [["w/o priming, w/o explanation", "w/o priming, w/ explanation"]], 2, 1, likert_x = True)
# Out:
# w/o priming, w/o explanation 0.17058302511704673 0.15196175485572944
# w/o priming, w/ explanation 0.30656418638364796 0.00789420813206545

# %%
scatter_subplots("total_trust", "ai_agreement", [[results_wo_0, results_w_0],[results_wo_1, results_w_1]], 
        [["w/o priming, w/o explanation", "w/o priming, w/ explanation"],
         ["w/ priming, w/o explanation", "w/ priming, w/ explanation"]],
        ncols = 2, nrows = 2, likert_x = True)
# Out:
# w/o priming, w/o explanation 0.26004272977279475 0.02738257376289528
# w/o priming, w/ explanation 0.17776480220635596 0.12970832265063967
# w/ priming, w/o explanation 0.048601205283689865 0.6726206552955749
# w/ priming, w/ explanation 0.3971436254299766 0.0004592523133215375

# %%
scatter_subplots("switch_ratio", "ai_agreement", [[results_wo_0, results_w_0]], 
        [["w/o explanation", "w/ explanation"]], nrows = 1, ncols = 2)
# Out:
# w/o explanation 0.6801959922524327 4.977256841235977e-11
# w/ explanation 0.7176392277148717 6.266153822694177e-13

# %% [markdown]
# **Summary**:
#
# There is a correlation between total trust (reported) and switch ratio only when participants got an explanation! (Note that we don't know the switch ratio for participants in the with priming group.)
#
# The case is similarly weird for the correlation between total trust and ai agreement:
# There is a correlation for participants who did get primed AND got an explanation, as well as for those who did not get primed and did not get an explanation.
#
# ## Trust Comparisons (Group 0)
#
# For the group without priming, we can also compare in more detail how the presence of explanation influences overtrust, undertrust, etc.

# %%
def compare_0(column):
    
    print(column.upper())
    
    print(stats.ttest_ind(results_w_0[column], results_wo_0[column]))

    fig, ax = plt.subplots()
    VP = ax.boxplot([results_w_0[column], results_wo_0[column]], labels = ["w/ explanation", "w/o explanation"])
    ax.set_title(column)
    plt.show()
    
def compare_0_multiple(columns, labels, nrows, ncols):
    
    fig, axs = plt.subplots(ncols = ncols, nrows = nrows, figsize = (8, 4*nrows))
    if nrows == 1:
        axs = np.array([axs])
    for row in range(nrows):
        for col in range(ncols):
            c = columns[row][col]
            print(labels[row][col], c.upper())
            print(stats.ttest_ind(results_wo_0[c], results_w_0[c]))
            axs[row, col].boxplot([results_wo_0[c], results_w_0[c]])
            axs[row, col].set_title(labels[row][col])
            axs[row, col].set_xticks([1, 2], labels=["w/o explanation", "w/ explanation"])
    plt.show()

# %%
compare_0_multiple([["n_wt", "n_wmt"], ["n_ot", "n_ut"]], 
                   [["Warranted Trust", "Warranted Mistrust"], ["Overtrust", "Undertrust"]], 
                   nrows = 2, ncols = 2)
# Out:
# Warranted Trust N_WT
# Ttest_indResult(statistic=0.40151321054340217, pvalue=0.6886375497122701)
# Warranted Mistrust N_WMT
# Ttest_indResult(statistic=0.052962261459792985, pvalue=0.957835378900091)
# Overtrust N_OT
# Ttest_indResult(statistic=-1.5398601828722427, pvalue=0.12578901852005125)
# Undertrust N_UT
# Ttest_indResult(statistic=1.410336860619143, pvalue=0.1605966835775868)

# %%
compare_0_multiple([["switch_ratio", "ai_agreement"]], 
                   [["switch_ratio", "ai_agreement"]], 
                   nrows = 1, ncols = 2)
# Out:
# switch_ratio SWITCH_RATIO
# Ttest_indResult(statistic=-0.8427728012245601, pvalue=0.4007531632080321)
# ai_agreement AI_AGREEMENT
# Ttest_indResult(statistic=-1.209784707368115, pvalue=0.22834380627194154)

# %% [markdown]
# # Qualitative Data

# %%
AI_exp_wo = {
    '0_3.csv': ["ChatGPT","Social Media"],
    '0_4.csv': ["Uni"],
    '0_5.csv': ["ChatBots"],
    '0_6.csv': ["ChatGPT"],
    '0_7.csv': ["Work", "Generative AI"],
    '0_8.csv': ["ChatGPT"],
    '0_9.csv': ["ChatGPT", "Photoshop AI"],
    '0_11.csv': ["ChatBots"],
    '0_13.csv': ["Whatsapp"],
    '0_14.csv': ["ChatGPT","Image Generators"],
    '0_15.csv': ["Uni"],
    '0_17.csv': ["Internet"],
    '0_18.csv': ["ChatGPT"],
    '0_19.csv': ["ChatGPT"],
    '0_22.csv': ["ChatGPT","Literature"],
    '0_24.csv': ["OpenAI", "Work","Personal"],
    '0_25.csv': ["Online Course"],
    '0_26.csv': ["Phone","Content Generation"],
    '0_27.csv': ["Work"],
    '0_33.csv': ["Uni"],
    '0_38.csv': ["ChatGPT"],
    '0_39.csv': ["ChatGPT","Everyday Life"],
    '0_40.csv': ["ChatGPT","PlaygroundAI"],
    '0_41.csv': ["Research"],
    '0_42.csv': ["ChatGPT"],
    '0_45.csv': ["BardAI","Stable Diffusion"],
    '0_46.csv': ["Work"],
    '0_49.csv': ["ChatGPT","Work"],
    '0_50.csv': ["Uni","Research"],
    '0_53.csv': ["ChatGPT"],
    '0_55.csv': ["ChatGPT","Internet"],
    '0_56.csv': ["Uni"],
    '0_57.csv': ["Daily"],
    '0_59.csv': ["ChatGPT"],
    '0_60.csv': ["Research Tool"],
    '0_64.csv': ["Media","Work"],
    '0_65.csv': ["ChatBots","Service Robot"],
    '0_66.csv': ["Internet"],
    '0_67.csv': ["ChatGPT","Midjourney"],
    '0_68.csv': ["Social Media","ChatGPT"],
    '0_69.csv': ["ChatGPT","Work"],
    '0_70.csv': ["Internet","Participation in other studies"],
    '0_71.csv': ["Bank App"],
    '0_72.csv': ["Internet"],
    '0_73.csv': ["ChatGPT","Image Generator"],
    '0_74.csv': ["Discussion among friends"],
    '0_75.csv': ["Research"],
    '0_76.csv': ["ChatGPT","Work"],
    '0_81.csv': ["ChatGPT","Content Generation"],
}

# Categories
# Context encountered (Uni, Work, Personal, Own Research) -> Maybe this should be Purpose? For work its a purpose but for uni its more context... hmmm
# Specific Tools (ChatGpt, Midjourney)
# General Categories of Tools (Chatbots, Image Generators)
# Frequency of Use
# Purpose for Use (Content Generation, Writing Emails)

# Weird:
#0_13 -> WHatsapp?
#0_17 -> Internet
#0_26 -> in my phone for writing content
#0_50 -> does "both supervised and unsupervised learning" mean supervised by a teacher and on their own? or is this about some machine learning topics the person did research about?
# 0_71 -> Bank app
# 0_81 -> "content creation platforms and educational platforms such as chat gpt" chat gpt as educational platform?

# Useless -> Grounds for general exclusion because they did not answer the questions in a way that makes sense?
# 0_30,0_61 -> Yes + No
# 0_35,0_47 -> Yes + no elaboration
# 0_51 -> Statement about perceived bias of the AI in the study?

# %%
print(results["AI_knowledge"].to_string())
# Out:
# wo_0_0                                                [NO, ]
# wo_0_1                                                [NO, ]
# wo_0_3     [YES, Through ChatGPT,  as well as discussions...
# wo_0_4     [YES, I am in a master of artificial inteligen...
# wo_0_5       [YES, I come into contact with ai in chat bots]
# wo_0_6                 [YES, through daily usage of chatgpt]
# wo_0_7     [YES, I rely on some artificial intelligences ...
# wo_0_8                           [YES, I have used chat GPT]
# wo_0_9          [YES, I have used chat gpt and photoshop ai]
# wo_0_10                                               [NO, ]
# wo_0_11                               [YES, chatting mostly]
# wo_0_12                                               [NO, ]
# wo_0_13             [YES, Well,  theres one on my whatsapp.]
# wo_0_14    [YES, ChatGPT,  more than one Ai images genera...
# wo_0_15    [YES, I'm studying Data Science and I took a c...
# wo_0_16                                               [NO, ]
# wo_0_17                                      [YES, Internet]
# wo_0_18        [YES, I have used ChatGPT for writing emails]
# wo_0_19                          [YES, Mostly with CHAT GPT]
# wo_0_20                                               [NO, ]
# wo_0_21                                               [NO, ]
# wo_0_22    [YES, I use chat gpt sometimes and have read a...
# wo_0_23                                               [NO, ]
# wo_0_24    [YES, I use open ai to help me with my job and...
# wo_0_25            [YES, online course about AI at coursera]
# wo_0_26    [YES, in my phone i normally use it for writin...
# wo_0_27                          [YES, i work in IT sectory]
# wo_0_30                                [YES, No i have not.]
# wo_0_33    [YES, Through my university degree,  the Unive...
# wo_0_34                                               [NO, ]
# wo_0_35                                              [YES, ]
# wo_0_37                                               [NO, ]
# wo_0_38                                       [YES, chatgpt]
# wo_0_39    [YES, Through ChatGPT,  in very basic ways in ...
# wo_0_40                        [YES, ChatGPT,  PlaygroundAI]
# wo_0_41    [YES, I used some to gather information about ...
# wo_0_42                [YES, Coding with ChatGPT assistance]
# wo_0_43                                               [NO, ]
# wo_0_44                                               [NO, ]
# wo_0_45    [YES, Through google's BARD AI and Stable Diff...
# wo_0_46                                       [YES, At work]
# wo_0_47                                             [YES, -]
# wo_0_48                                               [NO, ]
# wo_0_49    [YES, I used Chatgpt and other services in my ...
# wo_0_50    [YES, I am learning about how AI works (both s...
# wo_0_51    [YES, i think it was pretty biased towards the...
# wo_0_53                        [YES, mostly through ChatGPT]
# wo_0_54                                               [NO, ]
# wo_0_55                 [YES, through the internet. CHATGPT]
# wo_0_56    [YES, When I was writing some of my assignment...
# wo_0_57       [YES, I deal with this topic on a daily basis]
# wo_0_58                                               [NO, ]
# wo_0_59    [YES, I have been in contact with it through c...
# wo_0_60                   [YES, Used it as a research tool.]
# wo_0_61                                            [YES, NO]
# wo_0_62                                               [NO, ]
# wo_0_64                                [YES, Work and media]
# wo_0_65    [YES, Im mostly familiar and used AI chatbots ...
# wo_0_66                                      [YES, internet]
# wo_0_67                [YES, Chat  GPT,  Mildjourney,  etc.]
# wo_0_68    [YES, Through social media and engines like Ch...
# wo_0_69    [YES, I've used chatgpt and I'm a software eng...
# wo_0_70    [YES, by the internet and other questionnaires...
# wo_0_71                                   [YES, BANK'S APPS]
# wo_0_72                                      [YES, Internet]
# wo_0_73    [YES, ChatGPT basically,  and some other like ...
# wo_0_74    [YES, I have heard quite a lot of discussions ...
# wo_0_75                              [YES, through research]
# wo_0_76                       [YES, through work,  chat gpt]
# wo_0_77                                               [NO, ]
# wo_0_79                                               [NO, ]
# wo_0_80                                               [NO, ]
# wo_0_81    [YES, I have mostly come in contact with AI th...
# wo_1_0                               [YES, yes,  by chatgpt]
# wo_1_1                 [YES, through exploration and school]
# wo_1_2     [YES, It has been a big trend all over social ...
# wo_1_4                                                [NO, ]
# wo_1_5                                       [YES, probably]
# wo_1_6       [YES, used a lot of language models in college]
# wo_1_7                           [YES, Yes,  Chatgpt mostly]
# wo_1_8                   [YES, by recommendation of friends]
# wo_1_9                  [YES, Mostly through Youtube videos]
# wo_1_10                                [YES, I used chatGPT]
# wo_1_11                                               [NO, ]
# wo_1_13                                       [YES, ChatGPT]
# wo_1_14          [YES, i have been in contact with gpt chat]
# wo_1_15                                       [YES, ChatGPT]
# wo_1_16                                               [NO, ]
# wo_1_17    [YES, by using ai tools like chat gpt,  ai ima...
# wo_1_19                                               [NO, ]
# wo_1_20                                               [NO, ]
# wo_1_21      [YES, Using LLM's and learning using CChat-GPT]
# wo_1_22    [YES, With the various of program such as Copi...
# wo_1_23                                   [YES, yes chatgpt]
# wo_1_24                                               [NO, ]
# wo_1_25                                      [YES, chat gpt]
# wo_1_26                                       [YES, Chatgpt]
# wo_1_27                                 [YES, In University]
# wo_1_28    [YES, on the internet using Chat GPT and Leona...
# wo_1_29                               [YES, through chatgpt]
# wo_1_30                 [YES, Chatgpt and Midjourney mainly]
# wo_1_31    [YES, I use ChatGpt and Google Gard AI in a re...
# wo_1_32    [YES, I have not used an AI but I have seen ma...
# wo_1_33    [YES, Mostly through ChatGPT and other online ...
# wo_1_34    [YES, I was playing ChatGPT already and other ...
# wo_1_35    [YES, I often use ChatGPT to know more about h...
# wo_1_36                        [YES, I use it at my day job]
# wo_1_37                                               [NO, ]
# wo_1_38                                             [NO, 13]
# wo_1_39    [YES, Just with what i have used and looked at...
# wo_1_40                                       [YES, ChatGPT]
# wo_1_41                                       [YES, ChatGPT]
# wo_1_42    [YES, I have used different apps that include ...
# wo_1_43                                               [NO, ]
# wo_1_44                                     [YES, Chat bots]
# wo_1_45                                       [YES, chatgpt]
# wo_1_46                                               [NO, ]
# wo_1_47                                       [YES, chatgpt]
# wo_1_48                                       [YES, ChatGPT]
# wo_1_49                                               [NO, ]
# wo_1_50    [YES, ChatGPT,  and using it from curiosity to...
# wo_1_51            [YES, In my masters I',  working with AI]
# wo_1_52                                               [NO, ]
# wo_1_53    [YES, Cortana,  Siri,  Alex,  Google Assistant...
# wo_1_54    [YES, I've built very simple DSSes based off s...
# wo_1_55    [YES, I have used chat gpt before,  but not pr...
# wo_1_56                   [YES, picture generator,  chatbot]
# wo_1_57                                               [NO, ]
# wo_1_58                   [YES, I have an AI on my snapchat]
# wo_1_59    [YES, I practice to write motivational qoutes ...
# wo_1_60    [YES, On many of the platforms I use for video...
# wo_1_61        [YES, The use of chatGBT and microsoft bing.]
# wo_1_63                                       [YES, At work]
# wo_1_64                                 [YES, I use ChatGPT]
# wo_1_65            [YES, Different testing methods at work.]
# wo_1_66           [YES, chat GPT for example or With robots]
# wo_1_67                                           [YES, yes]
# wo_1_68                                               [NO, ]
# wo_1_69                                      [YES, chat gpt]
# wo_1_70    [YES, My first AI contact is by ChatGPT search...
# wo_1_71                                               [NO, ]
# wo_1_72                         [YES, ChatGPT,  Google Bard]
# wo_1_73         [YES, I use AI to assist me in organization]
# wo_1_74                                               [NO, ]
# wo_1_75                                               [NO, ]
# wo_1_76                      [YES, Through ChatGPT and Bing]
# wo_1_77    [YES, i've used chatgpt,  bard and image ai ge...
# wo_1_78                                               [NO, ]
# wo_1_79    [YES, I have used AI to generate answers to so...
# wo_1_80                                               [NO, ]
# wo_1_81        [YES, Mainly ChatGPT and AI image generators]
# w_0_0                                          [YES, Google]
# w_0_1                                         [YES, chatGPT]
# w_0_3            [YES, i frequently use it at my workplace.]
# w_0_4                                                 [NO, ]
# w_0_5                                                 [NO, ]
# w_0_6      [YES, I used chatgpt a lot,  as well of other ...
# w_0_7      [YES, On a daily basis we use AI in life,  in ...
# w_0_9      [YES, I sometimes used it in excel analysis to...
# w_0_10               [YES, Using it for marketing at my job]
# w_0_11                                                [NO, ]
# w_0_12     [YES, Day to day mostly. Ai image generation a...
# w_0_13     [YES, Light usage of chatbots and image genera...
# w_0_14                                 [YES, I know chatGBT]
# w_0_15                                                [NO, ]
# w_0_16                                            [YES, yes]
# w_0_17     [YES, Chatting with AI and using AI to do rese...
# w_0_18              [YES, Tech store when I go for shopping]
# w_0_20     [YES, Through search engines,  and social medi...
# w_0_22                                                [NO, ]
# w_0_23      [YES, I regularly use ChatGPT and Tortoise TTS.]
# w_0_24                                                [NO, ]
# w_0_25                          [YES, I've read an articale]
# w_0_26                                                [NO, ]
# w_0_27                          [YES, Through Data analysis]
# w_0_28                                     [YES, by hearsay]
# w_0_29                [YES, I've read about it occasionally]
# w_0_30                                                [NO, ]
# w_0_31                                                [NO, ]
# w_0_32     [YES, I am using AI to work,  it helps me when...
# w_0_33         [YES, Through videogames and YouTube videos.]
# w_0_34                    [YES, Through AI image generators]
# w_0_35         [YES, Chat GPT,  Bard - it helps me with SEO]
# w_0_36                                                [NO, ]
# w_0_37     [YES, chat gpt and ai chat bots that companies...
# w_0_38     [YES, I use it sometimes for college assignments]
# w_0_39                            [YES, Yes,  I use ChatGPT]
# w_0_40                                                [NO, ]
# w_0_41                                       [YES, chat gpt]
# w_0_42                                       [YES, Chat GPT]
# w_0_43                                                [NO, ]
# w_0_44                              [YES, Virtual platforms]
# w_0_45                                       [YES, Chatbots]
# w_0_46     [YES, I used chatGPT to improve my paragraph a...
# w_0_47                                  [YES, using chatgpt]
# w_0_48                                                [NO, ]
# w_0_49                                            [YES, yes]
# w_0_50                              [YES, I use AI everyday]
# w_0_51     [YES, I use it frequently when studying and ma...
# w_0_52                                                [NO, ]
# w_0_53                                                [NO, ]
# w_0_54                                   [YES, Used ChatGPT]
# w_0_56     [YES, Sometimes I use Chatgpt to help me with ...
# w_0_57                                                [NO, ]
# w_0_58                                       [YES, GPT chat]
# w_0_59                           [YES, mostly from chat gpt]
# w_0_60                                                [NO, ]
# w_0_61         [YES, chat gpt and other equivalent ai tools]
# w_0_62                                   [YES, AI chat bots]
# w_0_63                                                [NO, ]
# w_0_64                                                [NO, ]
# w_0_65                                      [YES, CHAT BOTS]
# w_0_66                                  [YES, Using ChatGPT]
# w_0_67                                                [NO, ]
# w_0_68                                        [YES, chatGPT]
# w_0_69                                [YES, Through varsity]
# w_0_70     [YES, I do a lot of chatbot training for work ...
# w_0_71             [YES, From what I have seen in the media]
# w_0_72     [YES, I'm a computer science graduate,  I'm fa...
# w_0_73     [YES, I've in contact with AI thrugh chatbots,...
# w_0_74                                     [YES, University]
# w_0_75     [YES, Through my work,  in college and also Ch...
# w_0_76                                                [NO, ]
# w_0_77                                 [YES, through openAI]
# w_0_78         [YES, I listen to AI covers on youtube daily]
# w_1_0      [YES, Bixby on samsung devices,  content recom...
# w_1_1                                             [YES, yes]
# w_1_2                      [YES, work and personal projects]
# w_1_3      [YES, firstly learned of it from a prolific st...
# w_1_4                                                 [NO, ]
# w_1_5                                                 [NO, ]
# w_1_6                                                 [NO, ]
# w_1_7                                         [YES, chatgpt]
# w_1_8      [YES, CHAT GPT AND VOCAL ISOLATION IN MUSIC PR...
# w_1_9                                      [YES, Yes I have]
# w_1_10     [YES, sometimes more like in tests with Chat GPT]
# w_1_12                                                [NO, ]
# w_1_13     [YES, Its everywhere. Mostly of times with app...
# w_1_14     [YES, trying to use Chat GPT to answer work qu...
# w_1_15                                [YES, Through ChatGPT]
# w_1_16                 [YES, Chatgtp someone recommended it]
# w_1_17                                      [YES, Workplace]
# w_1_18                                                [NO, ]
# w_1_19       [YES, have used AI to help me with assignments]
# w_1_20     [YES, Using a lot of diferent sites that use A...
# w_1_21     [YES, I heard about ChatGPT on the internet an...
# w_1_22     [YES, I am using some of the applications of A...
# w_1_23                                [YES, Through chatGBT]
# w_1_24                                                [NO, ]
# w_1_25                                       [YES, Chat gpt]
# w_1_26                                                [NO, ]
# w_1_27     [YES, Online and through learning about the to...
# w_1_30                                                [NO, ]
# w_1_31     [YES, I have come in contact with AI when doin...
# w_1_32                                       [YES, Chatbots]
# w_1_33     [YES, Internet,  Social Media videos and artic...
# w_1_34                                                [NO, ]
# w_1_35                                                [NO, ]
# w_1_36     [YES, ChatGPT,  as well as grammarly for helpi...
# w_1_37                         [YES, I use ChatGPT 4 daily.]
# w_1_38                                                [NO, ]
# w_1_39                          [YES, I needed help at work]
# w_1_40                            [YES, I have used ChatGPT]
# w_1_41                           [YES, by doing school work]
# w_1_42                           [YES, Through the internet]
# w_1_43     [YES, I am a computer science student,  so I h...
# w_1_44                                                [NO, ]
# w_1_45     [YES, through various applications such as cha...
# w_1_46                     [YES, A friend told me about it.]
# w_1_47                            [YES, i have used chatGPT]
# w_1_48                                                [NO, ]
# w_1_49                   [YES, A plethora of online sources]
# w_1_50     [YES, I'm interested in Technology. I've tried...
# w_1_51                                        [YES, ChatGPT]
# w_1_52     [YES, In surveys about AI and some texts writt...
# w_1_54                                                [NO, ]
# w_1_55     [YES, I've been using AI image generators test...
# w_1_56                                        [YES, ChatGPT]
# w_1_57     [YES, I'm listening podcasts and using some to...
# w_1_58     [YES, In every day life activities,  specially...
# w_1_59                 [YES, I've come across it in surveys]
# w_1_60        [YES, At work and in prior studies like these]
# w_1_61                                   [YES, Via Internet]
# w_1_62                                                [NO, ]
# w_1_63     [YES, Recently,  I have been using the online ...
# w_1_64                                                [NO, ]
# w_1_65                            [YES, I tried out ChatGPT]
# w_1_66     [YES, Sometimes I use open AI,  also I love re...
# w_1_67     [YES, I tried chatbots and I followed lessons ...
# w_1_68                                            [YES, Yes]
# w_1_69     [YES, I know various types of AI but never act...
# w_1_70                                                [NO, ]
# w_1_71     [YES, I have use AI tools to assist me in seve...
# w_1_72                                                [NO, ]
# w_1_73     [YES, I have used some AI casually and as part...
# w_1_74                                   [YES, chatgpt etc.]
# w_1_75                                                [NO, ]
# w_1_76                                       [YES, Chat GPT]
# w_1_77     [YES, I have some works where AI is applied in...
# w_1_79                                                [NO, ]
