# %%
import numpy as np
import pandas as pd
import pprint
import matplotlib.pyplot as plt
from scipy import stats
from collections import Counter

# %%
df = pd.read_csv("sample_string.csv", index_col = "Index")
df
# Out:
#       Marital status              Application mode  \
# Index
# 648           Single              Change in course
# 2781          Single  1st phase—general contingent
# 2883         Married             Over 23 years old
# 266           Single  2nd phase—general contingent
# 2537          Single  1st phase—general contingent
# 2791          Single  1st phase—general contingent
# 1576         Married             Over 23 years old
# 988           Single  1st phase—general contingent
# 3232          Single  1st phase—general contingent
# 3214          Single  1st phase—general contingent
# 131           Single  2nd phase—general contingent
# 3920          Single  1st phase—general contingent
# 3575          Single  1st phase—general contingent
# 3053          Single  2nd phase—general contingent
# 4096        Divorced             Over 23 years old
#
#        University's position in preferences when applying  \
# Index
# 648                                                    2
# 2781                                                   1
# 2883                                                   1
# 266                                                    4
# 2537                                                   1
# 2791                                                   1
# 1576                                                   2
# 988                                                    1
# 3232                                                   2
# 3214                                                   4
# 131                                                    2
# 3920                                                   5
# 3575                                                   1
# 3053                                                   1
# 4096                                                   1
#
#                                      Course Daytime/evening attendance  \
# Index
# 648                            Oral Hygiene                    daytime
# 2781                        Basic Education                    daytime
# 2883    Social Service (evening attendance)                    evening
# 266                                 Nursing                    daytime
# 2537   Advertising and Marketing Management                    daytime
# 2791                     Veterinary Nursing                    daytime
# 1576   Advertising and Marketing Management                    daytime
# 988                          Social Service                    daytime
# 3232           Journalism and Communication                    daytime
# 3214                   Communication Design                    daytime
# 131                    Communication Design                    daytime
# 3920                         Social Service                    daytime
# 3575                          Equiniculture                    daytime
# 3053                     Veterinary Nursing                    daytime
# 4096    Social Service (evening attendance)                    evening
#
#                                   Previous qualification Nationality  \
# Index
# 648                                  Secondary education  Portuguese
# 2781                                 Secondary education  Portuguese
# 2883                                 Secondary education  Portuguese
# 266                                  Secondary education  Portuguese
# 2537                                 Secondary education  Portuguese
# 2791                                 Secondary education  Portuguese
# 1576   Basic education 3rd cycle (9th/10th/11th year)...  Portuguese
# 988                                  Secondary education  Portuguese
# 3232                                 Secondary education  Portuguese
# 3214                                 Secondary education  Portuguese
# 131                                  Secondary education  Portuguese
# 3920                                 Secondary education  Portuguese
# 3575                                 Secondary education  Portuguese
# 3053                                 Secondary education  Portuguese
# 4096   Basic education 3rd cycle (9th/10th/11th year)...  Portuguese
#
#                                   Mother's qualification  \
# Index
# 648    Secondary Education—12th Year of Schooling or ...
# 2781         2nd cycle of the general high school course
# 2883       General Course of Administration and Commerce
# 266                     Higher Education—master’s degree
# 2537                             General commerce course
# 2791         Supplementary Accounting and Administration
# 1576       General Course of Administration and Commerce
# 988                   Higher Education—bachelor’s degree
# 3232                             General commerce course
# 3214                             Higher Education—degree
# 131        General Course of Administration and Commerce
# 3920         Supplementary Accounting and Administration
# 3575                    Higher Education—master’s degree
# 3053         Supplementary Accounting and Administration
# 4096       General Course of Administration and Commerce
#
#                                   Father's qualification  \
# Index
# 648    Basic Education 3rd Cycle (9th/10th/11th Year)...
# 2781   Basic education 1st cycle (4th/5th year) or eq...
# 2883   Basic education 1st cycle (4th/5th year) or eq...
# 266    Secondary Education—12th Year of Schooling or ...
# 2537   Basic Education 3rd Cycle (9th/10th/11th Year)...
# 2791   Basic Education 3rd Cycle (9th/10th/11th Year)...
# 1576   Basic education 1st cycle (4th/5th year) or eq...
# 988                   Higher Education—bachelor’s degree
# 3232   Basic Education 2nd Cycle (6th/7th/8th Year) o...
# 3214                             Higher Education—degree
# 131    Basic education 1st cycle (4th/5th year) or eq...
# 3920   Secondary Education—12th Year of Schooling or ...
# 3575                             Higher Education—degree
# 3053   Basic Education 3rd Cycle (9th/10th/11th Year)...
# 4096   Basic education 1st cycle (4th/5th year) or eq...
#
#                                      Mother's occupation  ...  \
# Index                                                     ...
# 648                                 Administrative staff  ...
# 2781                                   Unskilled Workers  ...
# 2883                                   Unskilled Workers  ...
# 266    Specialists in Intellectual and Scientific Act...  ...
# 2537   Skilled Workers in Industry, Construction, and...  ...
# 2791                                   Unskilled Workers  ...
# 1576                                   Unskilled Workers  ...
# 988       Intermediate Level Technicians and Professions  ...
# 3232      Intermediate Level Technicians and Professions  ...
# 3214   Specialists in Intellectual and Scientific Act...  ...
# 131                                    Unskilled Workers  ...
# 3920                                   Unskilled Workers  ...
# 3575      Intermediate Level Technicians and Professions  ...
# 3053                                             Student  ...
# 4096                                   Unskilled Workers  ...
#
#       Curricular units 2nd sem enrolled  \
# Index
# 648                                   8
# 2781                                  6
# 2883                                  6
# 266                                   8
# 2537                                  6
# 2791                                  6
# 1576                                  6
# 988                                   6
# 3232                                  6
# 3214                                  6
# 131                                   6
# 3920                                  6
# 3575                                  6
# 3053                                  5
# 4096                                  6
#
#       Total exams across all classes in 2nd sem  \
# Index
# 648                                          10
# 2781                                         14
# 2883                                          8
# 266                                           8
# 2537                                          6
# 2791                                          8
# 1576                                          9
# 988                                          12
# 3232                                          6
# 3214                                          6
# 131                                           6
# 3920                                         13
# 3575                                          9
# 3053                                          9
# 4096                                          6
#
#       Curricular units 2nd sem passed Curricular units 2nd sem grade  \
# Index
# 648                                 8                      13.212500
# 2781                                1                      11.000000
# 2883                                6                      11.500000
# 266                                 7                      14.828571
# 2537                                6                      15.833333
# 2791                                6                      14.142857
# 1576                                4                      13.750000
# 988                                 2                      10.000000
# 3232                                5                      12.600000
# 3214                                6                      15.166667
# 131                                 6                      13.000000
# 3920                                3                      11.000000
# 3575                                6                      14.857143
# 3053                                3                      13.000000
# 4096                                6                      15.500000
#
#       Curricular units 2nd sem without exams Unemployment rate at enrollment  \
# Index
# 648                                        0                            10.8
# 2781                                       0                            10.8
# 2883                                       0                             8.9
# 266                                        0                            12.7
# 2537                                       0                            12.4
# 2791                                       0                            11.1
# 1576                                       0                            12.4
# 988                                        0                            11.1
# 3232                                       0                            12.7
# 3214                                       0                             9.4
# 131                                        0                             7.6
# 3920                                       0                             9.4
# 3575                                       0                            11.1
# 3053                                       0                             7.6
# 4096                                       0                            11.1
#
#       Inflation rate at enrollment  GDP at enrollment    Target  AI prediction
# Index
# 648                            1.4               1.74  Graduate       Graduate
# 2781                           1.4               1.74   Dropout        Dropout
# 2883                           1.4               3.51  Graduate       Graduate
# 266                            3.7              -1.70  Graduate       Graduate
# 2537                           0.5               1.79  Graduate       Graduate
# 2791                           0.6               2.02  Graduate       Graduate
# 1576                           0.5               1.79   Dropout        Dropout
# 988                            0.6               2.02   Dropout        Dropout
# 3232                           3.7              -1.70  Graduate       Graduate
# 3214                          -0.8              -3.12  Graduate       Graduate
# 131                            2.6               0.32  Graduate       Graduate
# 3920                          -0.8              -3.12  Graduate        Dropout
# 3575                           0.6               2.02  Graduate        Dropout
# 3053                           2.6               0.32   Dropout       Graduate
# 4096                           0.6               2.02  Graduate        Dropout
#
# [15 rows x 36 columns]

# %%
# generating somewhat sensible explanations

explanations = {}

# firstly, lets look at numerical values.

# We will check for each column, if in order to predict "graduate" (as opposodes to "dropout") 
# the value should be high or low. 
# where there is no or barely any difference, we will consider the column irrelevant ("na"). 
# after visual explanations, the reasoning for all numerical columns seems to make sense.

df_grad = df[df["Target"] == "Graduate"]
df_drop = df[df["Target"] == "Dropout"]

for column in df:
    
    if df.dtypes[column] in ["int", "float64"]:
        
        grad_mean = np.mean(df_grad[column])
        drop_mean = np.mean(df_drop[column])
        
        if np.abs(grad_mean - drop_mean) < 0.5:
            explanations[column] = "na"
        else:
            if grad_mean > drop_mean:
                explanations[column] = "high"
            else:
                explanations[column] = "low"
        
        #print(column)
        #print("Graduates:", grad_mean)
        #print("Dropouts:", drop_mean)
        #print(explanations[column])
        #print()

        
print("---")

print("---")
explanations["GDP at enrollment"] = "na" # I don't want to have this in the explanations
pprint.pprint(explanations)
# Out:
# ---
# ---
# {'Age at enrollment': 'low',
#  'Curricular units 1st sem enrolled': 'high',
#  'Curricular units 1st sem grade': 'high',
#  'Curricular units 1st sem passed': 'high',
#  'Curricular units 1st sem recognized from previous education or work': 'na',
#  'Curricular units 1st sem without exams': 'na',
#  'Curricular units 2nd sem enrolled': 'high',
#  'Curricular units 2nd sem grade': 'high',
#  'Curricular units 2nd sem passed': 'high',
#  'Curricular units 2nd sem recognized from previous education or work': 'na',
#  'Curricular units 2nd sem without exams': 'na',
#  'GDP at enrollment': 'na',
#  'Inflation rate at enrollment': 'na',
#  'Total exams across all classes in 1st sem': 'low',
#  'Total exams across all classes in 2nd sem': 'low',
#  'Unemployment rate at enrollment': 'na',
#  "University's position in preferences when applying": 'high'}

# %%
# now, lets look at categorical values.
# in this case it doesn't make sense to save on piece of information (high/low) per column.
# instead, we will figure out for each column which category one should be to be classified grad or drop respectively.
# then, we will order to columns once for grad and once for drop. So that if you want to be grad, the best 
# explanation would be if in column x you were in category a, if not then the next best if in column y you were in 
# category d, and so on. 
# Then we can choose a threshold under which the difference is not interesting. Above that threshold, we will 
# highlight for each student all of the columns where they belong in the category that is a good explanation for 
# their prediction (maybe up to a max of something, will see)

explanations_grads = []
explanations_drops = []
        
for column in df:
    
    if not df.dtypes[column] in ["int", "float64"] and not column in ["Target","explanation_num","explanation_cat", "AI prediction"]:
        
        print(column)
        grad_counts = Counter(df_grad[column])
        grad_perc = {item:grad_counts[item]/11 for item in grad_counts}
        drop_counts = Counter(df_drop[column])
        drop_perc = {item:drop_counts[item]/4 for item in drop_counts}
        #print(grad_counts)
        #print(grad_perc)
        #print(drop_counts)
        #print(drop_perc)
        
        options = list(set(drop_counts.keys()).union(set(grad_counts.keys())))
        #print(options)
        #print()
        
        best_o_grad = None
        best_o_grad_value = 0
        best_o_drop = None
        best_o_drop_value = 0
        
        for o in options:
            #print(o)
            if o in grad_perc:
                g = grad_perc[o]
            else:
                g = 0
            if o in drop_perc:
                d = drop_perc[o]
            else:
                d = 0
            diff = g-d
            if diff > best_o_grad_value:
                best_o_grad_value = diff
                best_o_grad = o
            elif diff < best_o_drop_value:
                best_o_drop_value = diff
                best_o_drop = o
            #print("Grads:", g, "Drops:", d)
            #print("Diff:", g-d)
            #print()
            
        if not best_o_grad is None:
            explanations_grads.append((column, best_o_grad, best_o_grad_value))
        if not best_o_drop is None:
            explanations_drops.append((column, best_o_drop, abs(best_o_drop_value)))
            
        print("Grads should be", best_o_grad)
        print("Drops should be", best_o_drop)
        
        #print("Graduates:", {item:grad_counts[item]/11 for item in grad_counts})
        #print("Dropouts:", {item:drop_counts[item]/4 for item in drop_counts})

    print("-")
    
explanations_grads = sorted(explanations_grads, key = lambda x:x[2], reverse = True)
explanations_drops = sorted(explanations_drops, key = lambda x:x[2], reverse = True)

# from visual inspection, it seems that a difference of 0.15 is a pretty good cutoff to only get those
# categories where there actually is an interesting difference in the data.

# finally, we add these explanations to the main dict, as a little dict where we can look up what the correct options 
# should be for grad/drop respectively.

for e in explanations_grads:
    if e[2]>0.15:
        explanations[e[0]] = {"GRADUATE":[e[1], e[2]]}
    else:
        explanations[e[0]] = {"GRADUATE":["na",0]}
for e in explanations_drops:
    if e[2]>0.15:
        explanations[e[0]]["DROPOUT"] = [e[1], e[2]]
    else:
        explanations[e[0]]["DROPOUT"] = ["na",0]
        
# there values are reduced manually only for the majority option, to not always have this as the default explanation
explanations["Debtor"]["GRADUATE"][1]=0.151
explanations['Tuition fees up to date']["GRADUATE"][1]=0.151
explanations["Daytime/evening attendance"]["DROPOUT"] = ["na", 0]

pprint.pprint(explanations)
# Out:
# Marital status
# Grads should be Divorced
# Drops should be Married
# -
# Application mode
# Grads should be Change in course
# Drops should be 2nd phase—general contingent
# -
# -
# Course
# Grads should be Communication Design
# Drops should be Basic Education
# -
# Daytime/evening attendance
# Grads should be evening
# Drops should be daytime
# -
# Previous qualification
# Grads should be Secondary education
# Drops should be Basic education 3rd cycle (9th/10th/11th year) or equivalent
# -
# Nationality
# Grads should be None
# Drops should be None
# -
# Mother's qualification
# Grads should be Higher Education—master’s degree
# Drops should be 2nd cycle of the general high school course
# -
# Father's qualification
# Grads should be Higher Education—degree
# Drops should be Higher Education—bachelor’s degree
# -
# Mother's occupation
# Grads should be Specialists in Intellectual and Scientific Activities
# Drops should be Student
# -
# Father's occupation
# Grads should be Intermediate Level Technicians and Professions
# Drops should be Administrative staff
# -
# Student not living at home
# Grads should be no
# Drops should be yes
# -
# Educational special needs
# Grads should be None
# Drops should be None
# -
# Debtor
# Grads should be no
# Drops should be yes
# -
# Tuition fees up to date
# Grads should be yes
# Drops should be no
# -
# Gender
# Grads should be male
# Drops should be female
# -
# Scholarship holder
# Grads should be yes
# Drops should be no
# -
# -
# International
# Grads should be None
# Drops should be None
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# {'Age at enrollment': 'low',
#  'Application mode': {'DROPOUT': ['na', 0], 'GRADUATE': ['na', 0]},
#  'Course': {'DROPOUT': ['Basic Education', 0.25],
#             'GRADUATE': ['Communication Design', 0.18181818181818182]},
#  'Curricular units 1st sem enrolled': 'high',
#  'Curricular units 1st sem grade': 'high',
#  'Curricular units 1st sem passed': 'high',
#  'Curricular units 1st sem recognized from previous education or work': 'na',
#  'Curricular units 1st sem without exams': 'na',
#  'Curricular units 2nd sem enrolled': 'high',
#  'Curricular units 2nd sem grade': 'high',
#  'Curricular units 2nd sem passed': 'high',
#  'Curricular units 2nd sem recognized from previous education or work': 'na',
#  'Curricular units 2nd sem without exams': 'na',
#  'Daytime/evening attendance': {'DROPOUT': ['na', 0],
#                                 'GRADUATE': ['evening', 0.18181818181818182]},
#  'Debtor': {'DROPOUT': ['yes', 0.25], 'GRADUATE': ['no', 0.151]},
#  "Father's occupation": {'DROPOUT': ['Administrative staff', 0.25],
#                          'GRADUATE': ['Intermediate Level Technicians and '
#                                       'Professions',
#                                       0.36363636363636365]},
#  "Father's qualification": {'DROPOUT': ['Higher Education—bachelor’s degree',
#                                         0.25],
#                             'GRADUATE': ['Higher Education—degree',
#                                          0.18181818181818182]},
#  'GDP at enrollment': 'na',
#  'Gender': {'DROPOUT': ['na', 0], 'GRADUATE': ['na', 0]},
#  'Inflation rate at enrollment': 'na',
#  'Marital status': {'DROPOUT': ['Married', 0.1590909090909091],
#                     'GRADUATE': ['na', 0]},
#  "Mother's occupation": {'DROPOUT': ['Student', 0.25],
#                          'GRADUATE': ['Specialists in Intellectual and '
#                                       'Scientific Activities',
#                                       0.18181818181818182]},
#  "Mother's qualification": {'DROPOUT': ['2nd cycle of the general high school '
#                                         'course',
#                                         0.25],
#                             'GRADUATE': ['Higher Education—master’s degree',
#                                          0.18181818181818182]},
#  'Previous qualification': {'DROPOUT': ['Basic education 3rd cycle '
#                                         '(9th/10th/11th year) or equivalent',
#                                         0.1590909090909091],
#                             'GRADUATE': ['Secondary education',
#                                          0.15909090909090906]},
#  'Scholarship holder': {'DROPOUT': ['na', 0], 'GRADUATE': ['na', 0]},
#  'Student not living at home': {'DROPOUT': ['na', 0], 'GRADUATE': ['na', 0]},
#  'Total exams across all classes in 1st sem': 'low',
#  'Total exams across all classes in 2nd sem': 'low',
#  'Tuition fees up to date': {'DROPOUT': ['no', 0.25],
#                              'GRADUATE': ['yes', 0.151]},
#  'Unemployment rate at enrollment': 'na',
#  "University's position in preferences when applying": 'high'}

# %%
# in order to generate the explanations for each case, we look at the numerical columns of that case.
# we check if this person is particularly high or low compared to the mean over all people, 
# and whether the direction of high/low corresponds to the prediction by the AI.

# then, we check for which of the categorial columns the chosen category conforms to the ones identified above.

x_per_person_num = {}
x_per_person_cat = {}

for index, row in df.iterrows():
    
    # track which cols have the highest percent of other peoples lower/higher this one
    most_x_cols = []
    most_x_percent = 0
    
    # track which cols are the correct category for the prediction
    cat_x_cols = []
    
    print(row["Target"], row["AI prediction"])
    
    for column in df:
        
        # the high/low goal in the explanations dict generated above corresponds to what we want to see
        # in order to predict "graduate". That means if the prediction of the AI is "dropout", it should be
        # the opposite.
        
        # check how many others are below this person if the goal is high, or above if goal is low
        if column in explanations and not explanations[column] == "na":
            
            if explanations[column] in ["high", "low"]:

                #print(column, ":", row[column])
                #print(np.mean(df[column]))

                if row["AI prediction"] == "Graduate":
                    if explanations[column] == "high":
                        #print("is this high? G")
                        percent = len([o for o in df[column] if o < row[column]]) / 15
                    else:
                        #print("is this low? G")
                        percent = len([o for o in df[column] if o > row[column]]) / 15
                else:
                    if explanations[column] == "high":
                        #print("is this low? D")
                        percent = len([o for o in df[column] if o > row[column]]) / 15
                    else:
                        #print("is this high? D")
                        percent = len([o for o in df[column] if o < row[column]]) / 15

                #print(percent)

                if percent > most_x_percent:
                    most_x_percent = percent
                    most_x_cols = [column]
                elif percent == most_x_percent:
                    most_x_cols.append(column)
                
            # for the categorical explanations, we only have to check for which ones the student is in the correct
            # category according to their prediction.
            else:
                explaining_cat = explanations[column][row["AI prediction"].upper()]
                if explaining_cat[0] == row[column]:
                    cat_x_cols.append([column, explaining_cat[0], explaining_cat[1]]) 
                
                
        #print("-")
                
    print(most_x_cols, most_x_percent)
    x_per_person_num[index] = most_x_cols
    
    print(cat_x_cols)
    # if there are more than three cat cols, we will limit it to two, but allow more if there are more at the 
    # same exact value
    if len(cat_x_cols) > 2:
        cat_x_cols = sorted(cat_x_cols, key = lambda x:x[2], reverse = True)
        cutoff_value = cat_x_cols[1][2]
        cat_x_cols = [c for c in cat_x_cols if c[2]>=cutoff_value]
        print(cat_x_cols)
    x_per_person_cat[index] = cat_x_cols
            
    print("---")
# Out:
# Graduate Graduate
# ['Curricular units 2nd sem passed'] 0.9333333333333333
# [['Previous qualification', 'Secondary education', 0.15909090909090906], ["Father's occupation", 'Intermediate Level Technicians and Professions', 0.36363636363636365], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# [["Father's occupation", 'Intermediate Level Technicians and Professions', 0.36363636363636365], ['Previous qualification', 'Secondary education', 0.15909090909090906]]
# ---
# Dropout Dropout
# ['Total exams across all classes in 1st sem', 'Curricular units 1st sem grade', 'Total exams across all classes in 2nd sem', 'Curricular units 2nd sem passed'] 0.9333333333333333
# [['Course', 'Basic Education', 0.25], ["Mother's qualification", '2nd cycle of the general high school course', 0.25], ['Debtor', 'yes', 0.25], ['Tuition fees up to date', 'no', 0.25]]
# [['Course', 'Basic Education', 0.25], ["Mother's qualification", '2nd cycle of the general high school course', 0.25], ['Debtor', 'yes', 0.25], ['Tuition fees up to date', 'no', 0.25]]
# ---
# Graduate Graduate
# ['Total exams across all classes in 1st sem', 'Total exams across all classes in 2nd sem'] 0.4666666666666667
# [['Daytime/evening attendance', 'evening', 0.18181818181818182], ['Previous qualification', 'Secondary education', 0.15909090909090906], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# [['Daytime/evening attendance', 'evening', 0.18181818181818182], ['Previous qualification', 'Secondary education', 0.15909090909090906]]
# ---
# Graduate Graduate
# ['Curricular units 1st sem enrolled'] 0.9333333333333333
# [['Previous qualification', 'Secondary education', 0.15909090909090906], ["Mother's qualification", 'Higher Education—master’s degree', 0.18181818181818182], ["Mother's occupation", 'Specialists in Intellectual and Scientific Activities', 0.18181818181818182], ["Father's occupation", 'Intermediate Level Technicians and Professions', 0.36363636363636365], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# [["Father's occupation", 'Intermediate Level Technicians and Professions', 0.36363636363636365], ["Mother's qualification", 'Higher Education—master’s degree', 0.18181818181818182], ["Mother's occupation", 'Specialists in Intellectual and Scientific Activities', 0.18181818181818182]]
# ---
# Graduate Graduate
# ['Curricular units 2nd sem grade'] 0.9333333333333333
# [['Previous qualification', 'Secondary education', 0.15909090909090906], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# [['Previous qualification', 'Secondary education', 0.15909090909090906], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# ---
# Graduate Graduate
# ['Curricular units 1st sem grade'] 0.9333333333333333
# [['Previous qualification', 'Secondary education', 0.15909090909090906], ["Father's occupation", 'Intermediate Level Technicians and Professions', 0.36363636363636365], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# [["Father's occupation", 'Intermediate Level Technicians and Professions', 0.36363636363636365], ['Previous qualification', 'Secondary education', 0.15909090909090906]]
# ---
# Dropout Dropout
# ['Age at enrollment'] 0.9333333333333333
# [['Marital status', 'Married', 0.1590909090909091], ['Previous qualification', 'Basic education 3rd cycle (9th/10th/11th year) or equivalent', 0.1590909090909091]]
# ---
# Dropout Dropout
# ['Curricular units 2nd sem grade'] 0.9333333333333333
# [["Father's qualification", 'Higher Education—bachelor’s degree', 0.25], ["Father's occupation", 'Administrative staff', 0.25]]
# ---
# Graduate Graduate
# ['Age at enrollment', 'Total exams across all classes in 2nd sem'] 0.6666666666666666
# [['Previous qualification', 'Secondary education', 0.15909090909090906], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# [['Previous qualification', 'Secondary education', 0.15909090909090906], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# ---
# Graduate Graduate
# ["University's position in preferences when applying", 'Curricular units 2nd sem grade'] 0.8
# [['Course', 'Communication Design', 0.18181818181818182], ['Previous qualification', 'Secondary education', 0.15909090909090906], ["Father's qualification", 'Higher Education—degree', 0.18181818181818182], ["Mother's occupation", 'Specialists in Intellectual and Scientific Activities', 0.18181818181818182], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# [['Course', 'Communication Design', 0.18181818181818182], ["Father's qualification", 'Higher Education—degree', 0.18181818181818182], ["Mother's occupation", 'Specialists in Intellectual and Scientific Activities', 0.18181818181818182]]
# ---
# Graduate Graduate
# ['Total exams across all classes in 1st sem'] 0.8
# [['Course', 'Communication Design', 0.18181818181818182], ['Previous qualification', 'Secondary education', 0.15909090909090906], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# [['Course', 'Communication Design', 0.18181818181818182], ['Previous qualification', 'Secondary education', 0.15909090909090906]]
# ---
# Graduate Dropout
# ['Curricular units 1st sem grade', 'Total exams across all classes in 2nd sem'] 0.8666666666666667
# []
# ---
# Graduate Dropout
# ['Total exams across all classes in 2nd sem'] 0.5333333333333333
# []
# ---
# Dropout Graduate
# ['Total exams across all classes in 1st sem'] 0.9333333333333333
# [['Previous qualification', 'Secondary education', 0.15909090909090906], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# [['Previous qualification', 'Secondary education', 0.15909090909090906], ['Debtor', 'no', 0.151], ['Tuition fees up to date', 'yes', 0.151]]
# ---
# Graduate Dropout
# ['Age at enrollment'] 0.8
# [['Previous qualification', 'Basic education 3rd cycle (9th/10th/11th year) or equivalent', 0.1590909090909091]]
# ---

# %%
df["explanation_num"] = pd.Series(x_per_person_num)
df["explanation_cat"] = pd.Series(x_per_person_cat)
df
# Out:
#       Marital status              Application mode  \
# Index
# 648           Single              Change in course
# 2781          Single  1st phase—general contingent
# 2883         Married             Over 23 years old
# 266           Single  2nd phase—general contingent
# 2537          Single  1st phase—general contingent
# 2791          Single  1st phase—general contingent
# 1576         Married             Over 23 years old
# 988           Single  1st phase—general contingent
# 3232          Single  1st phase—general contingent
# 3214          Single  1st phase—general contingent
# 131           Single  2nd phase—general contingent
# 3920          Single  1st phase—general contingent
# 3575          Single  1st phase—general contingent
# 3053          Single  2nd phase—general contingent
# 4096        Divorced             Over 23 years old
#
#        University's position in preferences when applying  \
# Index
# 648                                                    2
# 2781                                                   1
# 2883                                                   1
# 266                                                    4
# 2537                                                   1
# 2791                                                   1
# 1576                                                   2
# 988                                                    1
# 3232                                                   2
# 3214                                                   4
# 131                                                    2
# 3920                                                   5
# 3575                                                   1
# 3053                                                   1
# 4096                                                   1
#
#                                      Course Daytime/evening attendance  \
# Index
# 648                            Oral Hygiene                    daytime
# 2781                        Basic Education                    daytime
# 2883    Social Service (evening attendance)                    evening
# 266                                 Nursing                    daytime
# 2537   Advertising and Marketing Management                    daytime
# 2791                     Veterinary Nursing                    daytime
# 1576   Advertising and Marketing Management                    daytime
# 988                          Social Service                    daytime
# 3232           Journalism and Communication                    daytime
# 3214                   Communication Design                    daytime
# 131                    Communication Design                    daytime
# 3920                         Social Service                    daytime
# 3575                          Equiniculture                    daytime
# 3053                     Veterinary Nursing                    daytime
# 4096    Social Service (evening attendance)                    evening
#
#                                   Previous qualification Nationality  \
# Index
# 648                                  Secondary education  Portuguese
# 2781                                 Secondary education  Portuguese
# 2883                                 Secondary education  Portuguese
# 266                                  Secondary education  Portuguese
# 2537                                 Secondary education  Portuguese
# 2791                                 Secondary education  Portuguese
# 1576   Basic education 3rd cycle (9th/10th/11th year)...  Portuguese
# 988                                  Secondary education  Portuguese
# 3232                                 Secondary education  Portuguese
# 3214                                 Secondary education  Portuguese
# 131                                  Secondary education  Portuguese
# 3920                                 Secondary education  Portuguese
# 3575                                 Secondary education  Portuguese
# 3053                                 Secondary education  Portuguese
# 4096   Basic education 3rd cycle (9th/10th/11th year)...  Portuguese
#
#                                   Mother's qualification  \
# Index
# 648    Secondary Education—12th Year of Schooling or ...
# 2781         2nd cycle of the general high school course
# 2883       General Course of Administration and Commerce
# 266                     Higher Education—master’s degree
# 2537                             General commerce course
# 2791         Supplementary Accounting and Administration
# 1576       General Course of Administration and Commerce
# 988                   Higher Education—bachelor’s degree
# 3232                             General commerce course
# 3214                             Higher Education—degree
# 131        General Course of Administration and Commerce
# 3920         Supplementary Accounting and Administration
# 3575                    Higher Education—master’s degree
# 3053         Supplementary Accounting and Administration
# 4096       General Course of Administration and Commerce
#
#                                   Father's qualification  \
# Index
# 648    Basic Education 3rd Cycle (9th/10th/11th Year)...
# 2781   Basic education 1st cycle (4th/5th year) or eq...
# 2883   Basic education 1st cycle (4th/5th year) or eq...
# 266    Secondary Education—12th Year of Schooling or ...
# 2537   Basic Education 3rd Cycle (9th/10th/11th Year)...
# 2791   Basic Education 3rd Cycle (9th/10th/11th Year)...
# 1576   Basic education 1st cycle (4th/5th year) or eq...
# 988                   Higher Education—bachelor’s degree
# 3232   Basic Education 2nd Cycle (6th/7th/8th Year) o...
# 3214                             Higher Education—degree
# 131    Basic education 1st cycle (4th/5th year) or eq...
# 3920   Secondary Education—12th Year of Schooling or ...
# 3575                             Higher Education—degree
# 3053   Basic Education 3rd Cycle (9th/10th/11th Year)...
# 4096   Basic education 1st cycle (4th/5th year) or eq...
#
#                                      Mother's occupation  ...  \
# Index                                                     ...
# 648                                 Administrative staff  ...
# 2781                                   Unskilled Workers  ...
# 2883                                   Unskilled Workers  ...
# 266    Specialists in Intellectual and Scientific Act...  ...
# 2537   Skilled Workers in Industry, Construction, and...  ...
# 2791                                   Unskilled Workers  ...
# 1576                                   Unskilled Workers  ...
# 988       Intermediate Level Technicians and Professions  ...
# 3232      Intermediate Level Technicians and Professions  ...
# 3214   Specialists in Intellectual and Scientific Act...  ...
# 131                                    Unskilled Workers  ...
# 3920                                   Unskilled Workers  ...
# 3575      Intermediate Level Technicians and Professions  ...
# 3053                                             Student  ...
# 4096                                   Unskilled Workers  ...
#
#       Curricular units 2nd sem passed Curricular units 2nd sem grade  \
# Index
# 648                                 8                      13.212500
# 2781                                1                      11.000000
# 2883                                6                      11.500000
# 266                                 7                      14.828571
# 2537                                6                      15.833333
# 2791                                6                      14.142857
# 1576                                4                      13.750000
# 988                                 2                      10.000000
# 3232                                5                      12.600000
# 3214                                6                      15.166667
# 131                                 6                      13.000000
# 3920                                3                      11.000000
# 3575                                6                      14.857143
# 3053                                3                      13.000000
# 4096                                6                      15.500000
#
#       Curricular units 2nd sem without exams Unemployment rate at enrollment  \
# Index
# 648                                        0                            10.8
# 2781                                       0                            10.8
# 2883                                       0                             8.9
# 266                                        0                            12.7
# 2537                                       0                            12.4
# 2791                                       0                            11.1
# 1576                                       0                            12.4
# 988                                        0                            11.1
# 3232                                       0                            12.7
# 3214                                       0                             9.4
# 131                                        0                             7.6
# 3920                                       0                             9.4
# 3575                                       0                            11.1
# 3053                                       0                             7.6
# 4096                                       0                            11.1
#
#       Inflation rate at enrollment GDP at enrollment    Target  AI prediction  \
# Index
# 648                            1.4              1.74  Graduate       Graduate
# 2781                           1.4              1.74   Dropout        Dropout
# 2883                           1.4              3.51  Graduate       Graduate
# 266                            3.7             -1.70  Graduate       Graduate
# 2537                           0.5              1.79  Graduate       Graduate
# 2791                           0.6              2.02  Graduate       Graduate
# 1576                           0.5              1.79   Dropout        Dropout
# 988                            0.6              2.02   Dropout        Dropout
# 3232                           3.7             -1.70  Graduate       Graduate
# 3214                          -0.8             -3.12  Graduate       Graduate
# 131                            2.6              0.32  Graduate       Graduate
# 3920                          -0.8             -3.12  Graduate        Dropout
# 3575                           0.6              2.02  Graduate        Dropout
# 3053                           2.6              0.32   Dropout       Graduate
# 4096                           0.6              2.02  Graduate        Dropout
#
#                                          explanation_num  \
# Index
# 648                    [Curricular units 2nd sem passed]
# 2781   [Total exams across all classes in 1st sem, Cu...
# 2883   [Total exams across all classes in 1st sem, To...
# 266                  [Curricular units 1st sem enrolled]
# 2537                    [Curricular units 2nd sem grade]
# 2791                    [Curricular units 1st sem grade]
# 1576                                 [Age at enrollment]
# 988                     [Curricular units 2nd sem grade]
# 3232   [Age at enrollment, Total exams across all cla...
# 3214   [University's position in preferences when app...
# 131          [Total exams across all classes in 1st sem]
# 3920   [Curricular units 1st sem grade, Total exams a...
# 3575         [Total exams across all classes in 2nd sem]
# 3053         [Total exams across all classes in 1st sem]
# 4096                                 [Age at enrollment]
#
#                                          explanation_cat
# Index
# 648    [[Father's occupation, Intermediate Level Tech...
# 2781   [[Course, Basic Education, 0.25], [Mother's qu...
# 2883   [[Daytime/evening attendance, evening, 0.18181...
# 266    [[Father's occupation, Intermediate Level Tech...
# 2537   [[Previous qualification, Secondary education,...
# 2791   [[Father's occupation, Intermediate Level Tech...
# 1576   [[Marital status, Married, 0.1590909090909091]...
# 988    [[Father's qualification, Higher Education—bac...
# 3232   [[Previous qualification, Secondary education,...
# 3214   [[Course, Communication Design, 0.181818181818...
# 131    [[Course, Communication Design, 0.181818181818...
# 3920                                                  []
# 3575                                                  []
# 3053   [[Previous qualification, Secondary education,...
# 4096   [[Previous qualification, Basic education 3rd ...
#
# [15 rows x 38 columns]

# %%
df.to_csv("sample_x.csv", index = "Index")
